# %%
from amnesiac import blurry_memory

# %%
blurry_memory(["CHUKN088IS", "1_L1K3TH4T"],190573735,1)
blurry_memory(["B000010000"],190573735,0)
# Out:
# {'B000010000': 0.41321352385720256}

# %%
# def fitness(population):
#     str_population = "".join(population)
#     score = blurry_memory([str_population],190573735,0)
#     return score[str_population]

# %%
# population = list("CHUKN088IS")
# fitness(population)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import time
import string

# %%
passcode_length = 10
# passcode_lower_bound = 0
# passcode_upper_bound = 9
passcode_options = list(string.digits+string.ascii_uppercase+_)
np.random.shuffle(passcode_options)
print(passcode_options)
# Out:
# ['6', 'Q', 'P', 'C', 'A', 'I', 'S', 'V', '8', 'H', '1', '3', '7', 'L', 'R', 'B', 'E', '4', 'N', 'Z', '0', 'O', 'M', 'X', '9', 'K', 'T', 'Y', '2', 'D', 'G', 'W', 'F', 'U', '5', 'J']

# %%
# int(round(random.uniform(passcode_lower_bound,passcode_upper_bound),0))

# %%
print(np.random.choice(passcode_options, 1)[0])
# Out:
# R

# %%
population_size = 250
num_parents = 70
elite_size = 20

# %%
# secret_passcode = []
# for x in range(passcode_length):
#     secret_passcode.append(str(np.random.choice(passcode_options, 1)[0]))
# #     secret_passcode.append(int(round(random.uniform(passcode_lower_bound,passcode_upper_bound),0)))

# print(secret_passcode)
# secret_passcode = list("e4e6ca42342f95978a17c6257593c1e1")
# len(list("e4e6ca42342f95978a17c6257593c1e1"))
# Out:
# 32

# %%
population = []
for i in range(population_size):
    chromosome = []
    for x in range(passcode_length):
#         chromosome.append(int(round(random.uniform(passcode_lower_bound,passcode_upper_bound),0)))
        chromosome.append(str(np.random.choice(passcode_options, 1)[0]))
    population.append(chromosome)

# %%
population
# Out:
# [['l',
#   'y',
#   'r',
#   'w',
#   '5',
#   '8',
#   'h',
#   'i',
#   'y',
#   'q',
#   'r',
#   'x',
#   'f',
#   '5',
#   '0',
#   'y',
#   'c',
#   'y',
#   'c',
#   '4',
#   'v',
#   'f',
#   '1',
#   'v',
#   'c',
#   'x',
#   'k',
#   'y',
#   'g',
#   'c',
#   '1',
#   '3'],
#  ['q',
#   't',
#   'c',
#   'd',
#   'u',
#   '6',
#   's',
#   '9',
#   'l',
#   'v',
#   'z',
#   'c',
#   'i',
#   'm',
#   '0',
#   'd',
#   'v',
#   '8',
#   '7',
#   'g',
#   'n',
#   '7',
#   '1',
#   'b',
#   'p',
#   'r',
#   '1',
#   'y',
#   'm',
#   '8',
#   'w',
#   '4'],
#  ['t',
#   'v',
#   'm',
#   's',
#   'k',
#   'n',
#   'j',
#   'x',
#   'f',
#   'z',
#   'b',
#   'w',
#   '0',
#   'z',
#   't',
#   'j',
#   '2',
#   '8',
#   's',
#   'v',
#   '7',
#   '7',
#   '2',
#   '6',
#   '6',
#   '8',
#   't',
#   'q',
#   'v',
#   'n',
#   '0',
#   'u'],
#  ['y',
#   'u',
#   'r',
#   'l',
#   '7',
#   '1',
#   'x',
#   '2',
#   '9',
#   'u',
#   'w',
#   'p',
#   'h',
#   'o',
#   'z',
#   'd',
#   'f',
#   '0',
#   '9',
#   '0',
#   'm',
#   '3',
#   'f',
#   'i',
#   'b',
#   'e',
#   '9',
#   'b',
#   't',
#   'w',
#   'k',
#   '3'],
#  ['i',
#   'z',
#   'b',
#   '1',
#   'b',
#   'c',
#   'f',
#   '2',
#   'f',
#   'h',
#   'x',
#   'o',
#   'b',
#   'i',
#   '2',
#   '5',
#   'm',
#   'f',
#   'q',
#   'p',
#   'f',
#   '8',
#   't',
#   '3',
#   'c',
#   'l',
#   'h',
#   'i',
#   'u',
#   'p',
#   'o',
#   'a'],
#  ['i',
#   'j',
#   'g',
#   '5',
#   'i',
#   'b',
#   '9',
#   'l',
#   '0',
#   '0',
#   'y',
#   'q',
#   '1',
#   'f',
#   'a',
#   'l',
#   'v',
#   'p',
#   'h',
#   'd',
#   't',
#   '1',
#   'h',
#   'x',
#   '4',
#   'b',
#   '0',
#   'c',
#   '6',
#   'a',
#   'z',
#   'n'],
#  ['2',
#   't',
#   '0',
#   'c',
#   'a',
#   'b',
#   '1',
#   't',
#   '2',
#   '0',
#   '4',
#   'l',
#   '1',
#   'a',
#   '3',
#   'l',
#   '2',
#   '5',
#   '2',
#   'x',
#   'f',
#   'c',
#   'h',
#   'f',
#   't',
#   '7',
#   'b',
#   'g',
#   '3',
#   '1',
#   'n',
#   'i'],
#  ['d',
#   'h',
#   '9',
#   '1',
#   'u',
#   'r',
#   'b',
#   '5',
#   'm',
#   '5',
#   'l',
#   'z',
#   'p',
#   'x',
#   'v',
#   '5',
#   'h',
#   'e',
#   'w',
#   '0',
#   'x',
#   '5',
#   'j',
#   '6',
#   '2',
#   'o',
#   'i',
#   'c',
#   'z',
#   'e',
#   '5',
#   'q'],
#  ['r',
#   '5',
#   'l',
#   '8',
#   '6',
#   'o',
#   '9',
#   's',
#   'r',
#   'f',
#   '6',
#   '5',
#   'q',
#   '4',
#   '5',
#   'w',
#   's',
#   's',
#   'u',
#   'q',
#   'x',
#   'v',
#   'k',
#   '3',
#   '1',
#   'g',
#   '4',
#   'g',
#   'v',
#   'o',
#   '9',
#   'y'],
#  ['w',
#   'a',
#   'y',
#   '1',
#   'o',
#   '4',
#   'a',
#   'a',
#   '3',
#   'n',
#   'i',
#   '4',
#   '4',
#   'k',
#   'n',
#   '3',
#   'o',
#   's',
#   'b',
#   'h',
#   'd',
#   '9',
#   'r',
#   'y',
#   '3',
#   'c',
#   '3',
#   'p',
#   'f',
#   '2',
#   '9',
#   'y'],
#  ['x',
#   'a',
#   'v',
#   'o',
#   '3',
#   't',
#   'x',
#   't',
#   '7',
#   'q',
#   '7',
#   '7',
#   'r',
#   'a',
#   'z',
#   'v',
#   'l',
#   '4',
#   '1',
#   'v',
#   'a',
#   '1',
#   'f',
#   'n',
#   'n',
#   '0',
#   '1',
#   'h',
#   'a',
#   '8',
#   's',
#   'r'],
#  ['s',
#   'y',
#   'l',
#   '3',
#   '8',
#   '7',
#   's',
#   '0',
#   'e',
#   'i',
#   'g',
#   't',
#   'm',
#   's',
#   'z',
#   'c',
#   'x',
#   '5',
#   'j',
#   '7',
#   'd',
#   'g',
#   'y',
#   'f',
#   'u',
#   '5',
#   '7',
#   'n',
#   'p',
#   '1',
#   'o',
#   'q'],
#  ['u',
#   'p',
#   'v',
#   'l',
#   'a',
#   'f',
#   '1',
#   'e',
#   'f',
#   '0',
#   'd',
#   '9',
#   'g',
#   'u',
#   '5',
#   '0',
#   '0',
#   'b',
#   'w',
#   'u',
#   'd',
#   '1',
#   'j',
#   'y',
#   'q',
#   'r',
#   'b',
#   't',
#   '9',
#   '9',
#   'o',
#   '3'],
#  ['h',
#   'a',
#   'f',
#   's',
#   't',
#   '4',
#   '5',
#   'y',
#   '6',
#   '0',
#   'r',
#   'k',
#   'r',
#   'u',
#   'q',
#   'f',
#   'c',
#   'y',
#   '8',
#   'm',
#   '3',
#   'a',
#   'z',
#   'g',
#   'u',
#   'g',
#   'u',
#   '5',
#   'o',
#   'p',
#   't',
#   'q'],
#  ['a',
#   'a',
#   '1',
#   'i',
#   '6',
#   'u',
#   'k',
#   '6',
#   '2',
#   't',
#   'p',
#   '4',
#   'o',
#   'b',
#   'a',
#   'q',
#   'h',
#   '4',
#   'u',
#   'b',
#   'o',
#   'e',
#   'i',
#   'l',
#   '1',
#   'a',
#   '1',
#   '6',
#   'f',
#   'f',
#   'l',
#   'x'],
#  ['i',
#   'i',
#   'n',
#   'z',
#   'r',
#   'j',
#   '5',
#   'q',
#   '1',
#   '0',
#   'n',
#   'j',
#   'a',
#   'i',
#   'y',
#   'g',
#   'h',
#   'a',
#   '4',
#   '3',
#   'm',
#   't',
#   'l',
#   'z',
#   'b',
#   'b',
#   't',
#   'k',
#   'c',
#   'q',
#   'o',
#   '9'],
#  ['l',
#   'p',
#   'k',
#   '5',
#   'w',
#   'a',
#   't',
#   '1',
#   '5',
#   'c',
#   't',
#   'k',
#   '0',
#   'r',
#   'j',
#   't',
#   '4',
#   '0',
#   '1',
#   'j',
#   't',
#   'f',
#   'a',
#   's',
#   'y',
#   'b',
#   'y',
#   'e',
#   'x',
#   'p',
#   'r',
#   'z'],
#  ['x',
#   'a',
#   'g',
#   '1',
#   '2',
#   '0',
#   'l',
#   '6',
#   '1',
#   'x',
#   'b',
#   'v',
#   'd',
#   'p',
#   '1',
#   '0',
#   '8',
#   'k',
#   'o',
#   'b',
#   'o',
#   '1',
#   'a',
#   'z',
#   '6',
#   '4',
#   's',
#   '9',
#   'x',
#   '3',
#   'c',
#   't'],
#  ['b',
#   'x',
#   'p',
#   'i',
#   'o',
#   '4',
#   'k',
#   'b',
#   '0',
#   'a',
#   '0',
#   'q',
#   'j',
#   'l',
#   'h',
#   'l',
#   'r',
#   'n',
#   'k',
#   'q',
#   '0',
#   'h',
#   'g',
#   'l',
#   'o',
#   'g',
#   '3',
#   'b',
#   't',
#   'r',
#   'i',
#   'h'],
#  ['e',
#   '7',
#   'b',
#   'j',
#   '8',
#   'g',
#   '3',
#   '5',
#   '7',
#   't',
#   'w',
#   '4',
#   '3',
#   'x',
#   'p',
#   'w',
#   'h',
#   'u',
#   'l',
#   '2',
#   '6',
#   'g',
#   '5',
#   '9',
#   '4',
#   'j',
#   '9',
#   'i',
#   'w',
#   '3',
#   'b',
#   '2'],
#  ['9',
#   '2',
#   'p',
#   '2',
#   'r',
#   'x',
#   'm',
#   '8',
#   'p',
#   'm',
#   '0',
#   'q',
#   '2',
#   'd',
#   'l',
#   'm',
#   'c',
#   'j',
#   '7',
#   'd',
#   'n',
#   '6',
#   'n',
#   '0',
#   '8',
#   '7',
#   'w',
#   'd',
#   'j',
#   't',
#   'f',
#   'i'],
#  ['m',
#   '6',
#   'o',
#   't',
#   't',
#   's',
#   'z',
#   'c',
#   'q',
#   'v',
#   'e',
#   'o',
#   'c',
#   '6',
#   'g',
#   'y',
#   'a',
#   'a',
#   'f',
#   '4',
#   '0',
#   '2',
#   'm',
#   '0',
#   's',
#   '6',
#   'y',
#   '9',
#   'p',
#   '4',
#   'i',
#   '1'],
#  ['k',
#   '0',
#   'b',
#   'p',
#   'q',
#   'u',
#   'w',
#   'n',
#   'q',
#   'a',
#   'f',
#   'u',
#   'q',
#   'z',
#   'y',
#   '1',
#   'd',
#   'u',
#   'v',
#   'j',
#   'd',
#   'n',
#   'j',
#   'w',
#   '4',
#   'a',
#   'u',
#   'k',
#   '0',
#   'o',
#   'j',
#   'l'],
#  ['k',
#   'c',
#   '6',
#   'l',
#   '0',
#   'h',
#   'q',
#   'b',
#   'v',
#   'v',
#   'x',
#   '7',
#   's',
#   '5',
#   'c',
#   'g',
#   'j',
#   'l',
#   '4',
#   'i',
#   'j',
#   'g',
#   'x',
#   '2',
#   '1',
#   'g',
#   '2',
#   'a',
#   'n',
#   'm',
#   'u',
#   'd'],
#  ['y',
#   'u',
#   'y',
#   'x',
#   '1',
#   's',
#   'e',
#   'v',
#   'q',
#   'a',
#   '5',
#   'p',
#   't',
#   't',
#   '7',
#   'x',
#   'u',
#   '3',
#   '3',
#   'a',
#   '3',
#   '8',
#   '5',
#   '6',
#   'f',
#   'i',
#   'b',
#   'v',
#   '8',
#   '3',
#   'i',
#   'p'],
#  ['u',
#   'e',
#   '7',
#   'h',
#   'f',
#   'y',
#   's',
#   'w',
#   's',
#   'z',
#   '1',
#   'f',
#   'g',
#   'u',
#   'z',
#   '5',
#   'n',
#   '7',
#   '0',
#   'i',
#   'g',
#   'd',
#   'u',
#   'd',
#   '2',
#   'a',
#   '5',
#   '3',
#   'r',
#   '6',
#   '5',
#   '5'],
#  ['c',
#   'g',
#   'f',
#   'b',
#   'c',
#   'f',
#   'a',
#   'i',
#   'h',
#   'x',
#   'a',
#   '8',
#   'w',
#   'k',
#   '0',
#   'n',
#   'd',
#   '5',
#   'g',
#   'v',
#   'z',
#   '1',
#   '7',
#   'n',
#   'p',
#   'm',
#   'u',
#   'b',
#   '9',
#   'm',
#   'u',
#   'f'],
#  ['7',
#   'd',
#   '1',
#   'o',
#   'y',
#   '1',
#   'x',
#   'i',
#   'q',
#   '8',
#   'd',
#   'j',
#   'k',
#   '0',
#   'k',
#   'v',
#   'i',
#   'r',
#   'r',
#   'l',
#   '2',
#   'p',
#   'f',
#   'r',
#   'n',
#   'm',
#   'm',
#   'f',
#   'h',
#   '9',
#   'p',
#   'v'],
#  ['8',
#   's',
#   'm',
#   '2',
#   '6',
#   'w',
#   '5',
#   '0',
#   '4',
#   'p',
#   'z',
#   's',
#   'q',
#   '3',
#   '3',
#   '1',
#   '9',
#   'm',
#   'l',
#   'k',
#   'y',
#   '8',
#   '9',
#   'y',
#   's',
#   'u',
#   'v',
#   'r',
#   '4',
#   'i',
#   '1',
#   '3'],
#  ['f',
#   'd',
#   'i',
#   'u',
#   't',
#   's',
#   'v',
#   'e',
#   'm',
#   '1',
#   's',
#   's',
#   '1',
#   'r',
#   'c',
#   '6',
#   'b',
#   'l',
#   'r',
#   'r',
#   'w',
#   'o',
#   '9',
#   'g',
#   '6',
#   '3',
#   'h',
#   'c',
#   'v',
#   '9',
#   'n',
#   'u'],
#  ['3',
#   '5',
#   'o',
#   't',
#   'b',
#   'f',
#   'j',
#   'a',
#   'm',
#   'f',
#   'u',
#   'a',
#   'z',
#   'b',
#   '5',
#   'r',
#   'm',
#   'd',
#   'c',
#   'r',
#   'q',
#   'm',
#   'p',
#   'i',
#   '2',
#   't',
#   '9',
#   'm',
#   'n',
#   'l',
#   '6',
#   'n'],
#  ['7',
#   'f',
#   '6',
#   'q',
#   'x',
#   'y',
#   'f',
#   'n',
#   '5',
#   '0',
#   'g',
#   'r',
#   'g',
#   'f',
#   'm',
#   'h',
#   '1',
#   'm',
#   'w',
#   'c',
#   'd',
#   'h',
#   '0',
#   '3',
#   'e',
#   't',
#   's',
#   'r',
#   'a',
#   'y',
#   't',
#   't'],
#  ['5',
#   'f',
#   'f',
#   'r',
#   'e',
#   'a',
#   's',
#   '9',
#   'r',
#   'f',
#   '6',
#   'k',
#   '6',
#   'r',
#   'r',
#   'm',
#   'e',
#   'y',
#   '5',
#   '4',
#   'd',
#   'm',
#   'f',
#   's',
#   'k',
#   '9',
#   '4',
#   'o',
#   'o',
#   'x',
#   'n',
#   'i'],
#  ['m',
#   'v',
#   's',
#   'v',
#   's',
#   'h',
#   'l',
#   'x',
#   'c',
#   'q',
#   '4',
#   'v',
#   'a',
#   '4',
#   'z',
#   'h',
#   'z',
#   'p',
#   '0',
#   's',
#   'x',
#   'h',
#   '4',
#   'u',
#   'g',
#   '0',
#   'e',
#   'x',
#   'v',
#   'r',
#   '0',
#   '4'],
#  ['6',
#   'w',
#   'q',
#   'n',
#   '7',
#   '7',
#   '1',
#   'g',
#   'v',
#   'p',
#   'd',
#   'u',
#   'd',
#   'j',
#   'j',
#   'i',
#   '1',
#   'h',
#   'o',
#   '3',
#   'k',
#   'h',
#   '3',
#   'a',
#   '2',
#   '9',
#   'c',
#   'e',
#   '1',
#   'd',
#   'g',
#   'h'],
#  ['1',
#   '1',
#   'f',
#   'i',
#   '3',
#   'h',
#   'x',
#   'x',
#   '6',
#   'd',
#   'x',
#   '3',
#   'm',
#   '8',
#   's',
#   'o',
#   't',
#   'd',
#   'y',
#   't',
#   'l',
#   '0',
#   'e',
#   'b',
#   'x',
#   'c',
#   'f',
#   'e',
#   '9',
#   'c',
#   'u',
#   't'],
#  ['v',
#   '7',
#   'f',
#   '5',
#   'h',
#   'c',
#   'q',
#   'g',
#   'c',
#   'x',
#   '8',
#   'a',
#   'w',
#   '6',
#   's',
#   '8',
#   'l',
#   'p',
#   'q',
#   '7',
#   '4',
#   'a',
#   'z',
#   '5',
#   '7',
#   't',
#   'b',
#   'b',
#   'u',
#   's',
#   'k',
#   't'],
#  ['k',
#   '2',
#   's',
#   '4',
#   'c',
#   'c',
#   'g',
#   'q',
#   'g',
#   'f',
#   'x',
#   'r',
#   '7',
#   '3',
#   't',
#   'a',
#   'e',
#   'i',
#   'u',
#   '4',
#   'g',
#   '5',
#   'c',
#   's',
#   '6',
#   '0',
#   'd',
#   'y',
#   'p',
#   '2',
#   'i',
#   '7'],
#  ['t',
#   '6',
#   'q',
#   'i',
#   'p',
#   'i',
#   '8',
#   'y',
#   '6',
#   't',
#   'h',
#   'i',
#   'x',
#   'g',
#   'v',
#   'g',
#   '4',
#   '6',
#   'u',
#   'a',
#   '1',
#   'm',
#   'd',
#   'a',
#   '8',
#   '3',
#   '5',
#   'i',
#   'n',
#   'v',
#   'b',
#   '0'],
#  ['d',
#   's',
#   'o',
#   'i',
#   'z',
#   'd',
#   'e',
#   'i',
#   'l',
#   '9',
#   'j',
#   'k',
#   'p',
#   '5',
#   'w',
#   't',
#   'a',
#   '4',
#   '0',
#   'j',
#   'h',
#   't',
#   'r',
#   '8',
#   'g',
#   'i',
#   'f',
#   'w',
#   'r',
#   't',
#   'i',
#   '6'],
#  ['i',
#   'x',
#   '7',
#   'c',
#   '3',
#   'c',
#   'u',
#   'j',
#   'x',
#   '9',
#   '2',
#   '3',
#   'l',
#   'i',
#   'r',
#   'm',
#   '9',
#   'g',
#   'p',
#   '9',
#   '0',
#   '9',
#   'x',
#   'o',
#   'u',
#   'n',
#   'b',
#   'f',
#   'k',
#   'a',
#   'n',
#   'l'],
#  ['a',
#   'e',
#   '5',
#   'w',
#   't',
#   '3',
#   '3',
#   '3',
#   '7',
#   'i',
#   'w',
#   'p',
#   'j',
#   'e',
#   '8',
#   'o',
#   't',
#   'o',
#   'e',
#   '1',
#   '7',
#   'm',
#   'a',
#   '6',
#   's',
#   '7',
#   'p',
#   'b',
#   '2',
#   't',
#   'i',
#   'c'],
#  ['k',
#   'c',
#   'p',
#   '4',
#   'm',
#   'f',
#   'z',
#   '3',
#   'q',
#   'e',
#   'j',
#   '4',
#   '6',
#   '2',
#   '5',
#   'a',
#   '5',
#   'c',
#   'h',
#   's',
#   'w',
#   'k',
#   '1',
#   'x',
#   'm',
#   'b',
#   '9',
#   '8',
#   '2',
#   'g',
#   'b',
#   '6'],
#  ['3',
#   'c',
#   'j',
#   'u',
#   'a',
#   '9',
#   '7',
#   '3',
#   '5',
#   'm',
#   'v',
#   'c',
#   'l',
#   'h',
#   'g',
#   'q',
#   '2',
#   '7',
#   '3',
#   'z',
#   'o',
#   '2',
#   '9',
#   'a',
#   'l',
#   '9',
#   'q',
#   'p',
#   'e',
#   'q',
#   's',
#   'p'],
#  ['h',
#   't',
#   'o',
#   'c',
#   'm',
#   'e',
#   'o',
#   '9',
#   's',
#   '4',
#   'o',
#   '6',
#   '0',
#   '4',
#   'h',
#   'l',
#   'q',
#   'b',
#   'm',
#   'j',
#   '3',
#   'q',
#   '6',
#   'r',
#   'h',
#   't',
#   'y',
#   'c',
#   'b',
#   '2',
#   'd',
#   'f'],
#  ['h',
#   '4',
#   'o',
#   'h',
#   '4',
#   'u',
#   'b',
#   'b',
#   'i',
#   '7',
#   'n',
#   'l',
#   'b',
#   'w',
#   'r',
#   'i',
#   'n',
#   'a',
#   'p',
#   'a',
#   'f',
#   '0',
#   'j',
#   'n',
#   '0',
#   '8',
#   '8',
#   'p',
#   'm',
#   't',
#   'l',
#   'p'],
#  ['8',
#   'k',
#   '9',
#   '6',
#   'x',
#   'w',
#   '5',
#   'x',
#   'a',
#   'p',
#   '9',
#   'g',
#   'y',
#   'a',
#   'v',
#   'a',
#   'e',
#   'k',
#   'e',
#   '3',
#   's',
#   'f',
#   'h',
#   'h',
#   '0',
#   '2',
#   '8',
#   '5',
#   'c',
#   'j',
#   'e',
#   'y'],
#  ['x',
#   'h',
#   't',
#   'u',
#   'o',
#   'y',
#   '1',
#   's',
#   'q',
#   'd',
#   'i',
#   'v',
#   '0',
#   'p',
#   't',
#   'f',
#   'a',
#   'r',
#   's',
#   'i',
#   'g',
#   'b',
#   '6',
#   '9',
#   '6',
#   '0',
#   '2',
#   'u',
#   'o',
#   'b',
#   'x',
#   'b'],
#  ['y',
#   'w',
#   'p',
#   '2',
#   'a',
#   'u',
#   'f',
#   'q',
#   'z',
#   'c',
#   '6',
#   'm',
#   'm',
#   'y',
#   'r',
#   's',
#   '2',
#   'y',
#   'b',
#   'x',
#   'g',
#   'h',
#   'u',
#   'z',
#   'n',
#   'y',
#   't',
#   'o',
#   'h',
#   'i',
#   'k',
#   'g'],
#  ['t',
#   '6',
#   '1',
#   'f',
#   'e',
#   '1',
#   'j',
#   'l',
#   'c',
#   'u',
#   'e',
#   'o',
#   '2',
#   'm',
#   'v',
#   '7',
#   'k',
#   '8',
#   'q',
#   '9',
#   'e',
#   '6',
#   's',
#   'v',
#   'u',
#   's',
#   'i',
#   'g',
#   'u',
#   'r',
#   'b',
#   's'],
#  ['2',
#   's',
#   '4',
#   'j',
#   'i',
#   '4',
#   '1',
#   'i',
#   '4',
#   'z',
#   'm',
#   '8',
#   'y',
#   'u',
#   'v',
#   '8',
#   '7',
#   '3',
#   'i',
#   'p',
#   '8',
#   'i',
#   'o',
#   'i',
#   's',
#   'w',
#   'n',
#   '1',
#   'e',
#   'd',
#   '9',
#   'i'],
#  ['w',
#   'u',
#   'u',
#   'v',
#   '6',
#   'j',
#   'p',
#   'i',
#   'j',
#   '9',
#   'o',
#   'q',
#   'e',
#   'g',
#   'c',
#   'u',
#   '5',
#   'g',
#   '9',
#   'k',
#   'g',
#   'p',
#   'v',
#   'd',
#   'g',
#   '8',
#   '0',
#   'i',
#   'y',
#   '9',
#   'z',
#   'm'],
#  ['3',
#   'b',
#   'b',
#   't',
#   'd',
#   't',
#   '1',
#   't',
#   'h',
#   'e',
#   'h',
#   'g',
#   'd',
#   'w',
#   'p',
#   'l',
#   'r',
#   '2',
#   'j',
#   'n',
#   '3',
#   '1',
#   '6',
#   'f',
#   'g',
#   't',
#   'x',
#   'c',
#   '6',
#   '4',
#   'c',
#   'w'],
#  ['y',
#   '4',
#   '8',
#   'u',
#   '2',
#   's',
#   'u',
#   'a',
#   '5',
#   'f',
#   'l',
#   'i',
#   '8',
#   '2',
#   'f',
#   'f',
#   'r',
#   'b',
#   'n',
#   'j',
#   'd',
#   'd',
#   '3',
#   'n',
#   '8',
#   's',
#   'a',
#   'g',
#   'v',
#   'e',
#   'l',
#   '7'],
#  ['m',
#   'f',
#   'f',
#   '7',
#   '4',
#   '5',
#   'u',
#   'w',
#   '5',
#   'i',
#   'u',
#   'n',
#   'e',
#   'h',
#   'w',
#   '4',
#   '6',
#   '2',
#   's',
#   'r',
#   'z',
#   '0',
#   'f',
#   'w',
#   'q',
#   '6',
#   '9',
#   'f',
#   'y',
#   'm',
#   'h',
#   'j'],
#  ['y',
#   'v',
#   'a',
#   'f',
#   'f',
#   'n',
#   'n',
#   'v',
#   '9',
#   'j',
#   '2',
#   '0',
#   'o',
#   'n',
#   '9',
#   'y',
#   'k',
#   'l',
#   'k',
#   'n',
#   'l',
#   '0',
#   'm',
#   'j',
#   '1',
#   '7',
#   'w',
#   'z',
#   'd',
#   'f',
#   '1',
#   'x'],
#  ['k',
#   'e',
#   'g',
#   't',
#   'd',
#   'b',
#   '9',
#   'g',
#   'c',
#   'w',
#   'k',
#   's',
#   '2',
#   'd',
#   '5',
#   'k',
#   'w',
#   'z',
#   'v',
#   'f',
#   '4',
#   'o',
#   'j',
#   '2',
#   '5',
#   '0',
#   'd',
#   '2',
#   '0',
#   'n',
#   'm',
#   'm'],
#  ['u',
#   'x',
#   'i',
#   'h',
#   'f',
#   'u',
#   'v',
#   'i',
#   '9',
#   'l',
#   'm',
#   't',
#   'f',
#   '1',
#   '7',
#   'w',
#   'g',
#   'n',
#   'h',
#   '4',
#   'c',
#   '8',
#   'w',
#   'r',
#   'h',
#   'd',
#   'r',
#   'n',
#   'g',
#   'y',
#   'q',
#   't'],
#  ['b',
#   'x',
#   'f',
#   '6',
#   'l',
#   'j',
#   'i',
#   's',
#   'v',
#   'f',
#   'm',
#   '6',
#   '2',
#   'a',
#   'i',
#   'o',
#   'z',
#   'p',
#   '6',
#   'd',
#   'i',
#   'n',
#   't',
#   'j',
#   '5',
#   'n',
#   '1',
#   'm',
#   's',
#   'q',
#   '9',
#   '1'],
#  ['v',
#   '0',
#   '2',
#   '6',
#   '7',
#   '8',
#   '9',
#   's',
#   '0',
#   'b',
#   '0',
#   '8',
#   'o',
#   'e',
#   'm',
#   '8',
#   'l',
#   'i',
#   'm',
#   '6',
#   'd',
#   'r',
#   'k',
#   '2',
#   't',
#   '4',
#   'o',
#   'q',
#   'q',
#   '6',
#   '1',
#   '2'],
#  ['m',
#   'd',
#   'p',
#   's',
#   'v',
#   'f',
#   '0',
#   'z',
#   '2',
#   'h',
#   'e',
#   'q',
#   'l',
#   'o',
#   'j',
#   'y',
#   'h',
#   't',
#   '2',
#   'l',
#   'k',
#   'v',
#   '6',
#   'v',
#   '2',
#   '0',
#   '1',
#   'z',
#   'k',
#   'r',
#   'q',
#   'n'],
#  ['g',
#   'g',
#   'e',
#   'j',
#   '4',
#   'q',
#   '7',
#   'e',
#   'o',
#   'e',
#   'y',
#   'd',
#   'g',
#   'x',
#   'o',
#   'r',
#   'b',
#   '3',
#   'b',
#   'a',
#   '7',
#   'd',
#   'n',
#   'g',
#   'h',
#   'h',
#   'm',
#   '0',
#   'k',
#   'k',
#   'e',
#   '9'],
#  ['x',
#   'p',
#   'a',
#   'n',
#   's',
#   'w',
#   't',
#   'a',
#   '4',
#   '9',
#   'k',
#   's',
#   '9',
#   '4',
#   'z',
#   'u',
#   'r',
#   '6',
#   '6',
#   'e',
#   '2',
#   'c',
#   'p',
#   '5',
#   'd',
#   'd',
#   '6',
#   '6',
#   '7',
#   '1',
#   '3',
#   '8'],
#  ['s',
#   '0',
#   'm',
#   'b',
#   't',
#   'i',
#   't',
#   '4',
#   'd',
#   'i',
#   'q',
#   'j',
#   'p',
#   '3',
#   '5',
#   '2',
#   'u',
#   'y',
#   'd',
#   's',
#   'z',
#   'k',
#   'b',
#   'f',
#   'g',
#   '2',
#   'd',
#   'f',
#   '1',
#   '6',
#   '5',
#   'b'],
#  ['1',
#   'u',
#   'g',
#   'n',
#   'i',
#   'w',
#   'q',
#   '5',
#   'p',
#   's',
#   'p',
#   'n',
#   'e',
#   '4',
#   '1',
#   'i',
#   'n',
#   'w',
#   'e',
#   'q',
#   'g',
#   '1',
#   '4',
#   'n',
#   'p',
#   'a',
#   '6',
#   'w',
#   'u',
#   's',
#   'u',
#   'u'],
#  ['6',
#   '6',
#   'y',
#   'w',
#   'f',
#   '6',
#   '8',
#   'h',
#   'z',
#   'w',
#   '2',
#   'c',
#   '8',
#   'd',
#   'm',
#   '1',
#   'j',
#   'x',
#   't',
#   'v',
#   'u',
#   '1',
#   'v',
#   'i',
#   'p',
#   'e',
#   'e',
#   'j',
#   '7',
#   'n',
#   'g',
#   'f'],
#  ['h',
#   'e',
#   's',
#   '4',
#   'w',
#   'l',
#   'w',
#   't',
#   '0',
#   '6',
#   '8',
#   '2',
#   'l',
#   '9',
#   'y',
#   'v',
#   'b',
#   'm',
#   'k',
#   'q',
#   'c',
#   't',
#   'i',
#   'g',
#   's',
#   'd',
#   'z',
#   'p',
#   'w',
#   '7',
#   'l',
#   'f'],
#  ['g',
#   'e',
#   'b',
#   'f',
#   'j',
#   'a',
#   'x',
#   'a',
#   '7',
#   'i',
#   '0',
#   'p',
#   'd',
#   't',
#   'r',
#   '8',
#   '5',
#   'd',
#   '9',
#   'a',
#   'a',
#   '3',
#   '9',
#   '1',
#   '8',
#   't',
#   'x',
#   '1',
#   'r',
#   'w',
#   '7',
#   'm'],
#  ['2',
#   'd',
#   'x',
#   'l',
#   'f',
#   'k',
#   '0',
#   '7',
#   'r',
#   'd',
#   'c',
#   'k',
#   'j',
#   'e',
#   'g',
#   'y',
#   '3',
#   'p',
#   'q',
#   'r',
#   'd',
#   'w',
#   'l',
#   'l',
#   'y',
#   'a',
#   'j',
#   'a',
#   'j',
#   'y',
#   'q',
#   'w'],
#  ['j',
#   '4',
#   'p',
#   'g',
#   'w',
#   't',
#   '4',
#   '4',
#   'b',
#   'i',
#   's',
#   'w',
#   'r',
#   'd',
#   '8',
#   'e',
#   'm',
#   's',
#   'g',
#   'k',
#   'a',
#   'j',
#   '3',
#   '1',
#   '5',
#   'v',
#   '0',
#   'l',
#   'q',
#   '2',
#   '7',
#   'j'],
#  ['r',
#   'z',
#   'q',
#   'o',
#   '8',
#   '6',
#   'e',
#   'o',
#   'l',
#   'o',
#   'i',
#   'z',
#   '2',
#   'n',
#   'z',
#   '1',
#   'k',
#   'o',
#   's',
#   '2',
#   'e',
#   'i',
#   '5',
#   'x',
#   'a',
#   '6',
#   '3',
#   'k',
#   '3',
#   '5',
#   '4',
#   'y'],
#  ['7',
#   '8',
#   'x',
#   '9',
#   '4',
#   'y',
#   '1',
#   'j',
#   'm',
#   'q',
#   'x',
#   'l',
#   'h',
#   'o',
#   'e',
#   '8',
#   'x',
#   'a',
#   '2',
#   'h',
#   'x',
#   'a',
#   'u',
#   'o',
#   'j',
#   'o',
#   '1',
#   'd',
#   's',
#   'e',
#   'v',
#   'm'],
#  ['e',
#   'o',
#   'v',
#   'm',
#   'x',
#   'z',
#   '1',
#   'g',
#   'v',
#   '5',
#   '1',
#   'e',
#   '9',
#   'i',
#   '5',
#   'u',
#   'v',
#   '2',
#   'r',
#   'f',
#   'z',
#   'l',
#   'm',
#   'f',
#   'f',
#   'h',
#   'u',
#   'q',
#   'x',
#   '9',
#   'z',
#   'u'],
#  ['1',
#   'f',
#   'e',
#   '4',
#   'f',
#   'c',
#   'n',
#   '3',
#   'o',
#   'c',
#   '7',
#   'o',
#   '0',
#   '0',
#   'x',
#   'h',
#   'h',
#   'n',
#   'b',
#   't',
#   't',
#   'l',
#   'q',
#   '8',
#   '4',
#   'h',
#   'c',
#   'y',
#   '3',
#   'w',
#   'e',
#   'd'],
#  ['f',
#   'n',
#   'y',
#   '7',
#   'd',
#   'k',
#   'e',
#   'j',
#   'c',
#   'm',
#   'k',
#   'l',
#   'i',
#   '4',
#   'j',
#   'm',
#   '3',
#   '6',
#   '3',
#   'o',
#   'x',
#   '1',
#   'x',
#   'k',
#   'f',
#   'q',
#   'e',
#   '1',
#   'w',
#   'f',
#   'i',
#   '1'],
#  ['f',
#   '7',
#   'j',
#   'y',
#   '0',
#   '5',
#   'i',
#   'h',
#   'l',
#   'x',
#   'b',
#   '0',
#   'm',
#   '3',
#   'z',
#   'y',
#   'n',
#   'v',
#   'i',
#   '6',
#   'y',
#   '9',
#   's',
#   'p',
#   'm',
#   'k',
#   'd',
#   'p',
#   'h',
#   'c',
#   'u',
#   '2'],
#  ['2',
#   'w',
#   '0',
#   'u',
#   'z',
#   'x',
#   'c',
#   '3',
#   'y',
#   '5',
#   'g',
#   't',
#   'p',
#   '2',
#   'b',
#   'i',
#   'p',
#   'c',
#   's',
#   '1',
#   'f',
#   '6',
#   'c',
#   'z',
#   '8',
#   'e',
#   '2',
#   'v',
#   'o',
#   '8',
#   'h',
#   'j'],
#  ['l',
#   'a',
#   'p',
#   '4',
#   '9',
#   '9',
#   'v',
#   'r',
#   'f',
#   't',
#   't',
#   'k',
#   'o',
#   'd',
#   'v',
#   'e',
#   '6',
#   'k',
#   '9',
#   'h',
#   '3',
#   'i',
#   'x',
#   '4',
#   'c',
#   'j',
#   '9',
#   'i',
#   '1',
#   'l',
#   '5',
#   'v'],
#  ['0',
#   'd',
#   '0',
#   'd',
#   'k',
#   'p',
#   'e',
#   'l',
#   '1',
#   'd',
#   '8',
#   'x',
#   'q',
#   'p',
#   'i',
#   't',
#   '6',
#   'a',
#   'o',
#   'n',
#   'i',
#   's',
#   '1',
#   'b',
#   'j',
#   'o',
#   's',
#   'b',
#   'x',
#   'w',
#   'x',
#   '4'],
#  ['d',
#   '7',
#   '3',
#   'g',
#   'b',
#   '0',
#   '9',
#   '6',
#   'x',
#   'm',
#   'a',
#   '8',
#   'p',
#   '6',
#   'n',
#   '7',
#   'h',
#   'k',
#   'i',
#   'z',
#   'j',
#   'o',
#   '0',
#   'j',
#   'u',
#   '8',
#   '0',
#   'w',
#   '6',
#   '5',
#   'm',
#   'c'],
#  ['y',
#   '2',
#   's',
#   '7',
#   'w',
#   '9',
#   'n',
#   '0',
#   '0',
#   's',
#   '1',
#   'j',
#   'w',
#   'y',
#   'p',
#   '5',
#   '7',
#   'm',
#   '4',
#   't',
#   '3',
#   'k',
#   'g',
#   'd',
#   'k',
#   'r',
#   'w',
#   '3',
#   'j',
#   'k',
#   's',
#   'p'],
#  ['z',
#   'e',
#   'u',
#   'a',
#   '8',
#   'q',
#   'v',
#   'r',
#   'u',
#   'e',
#   'f',
#   'q',
#   '9',
#   '2',
#   'f',
#   's',
#   'z',
#   '5',
#   'n',
#   'u',
#   'g',
#   'o',
#   's',
#   'k',
#   'm',
#   'b',
#   'i',
#   'p',
#   'l',
#   'e',
#   'k',
#   'h'],
#  ['q',
#   'x',
#   'i',
#   '6',
#   '8',
#   'f',
#   '0',
#   'h',
#   'o',
#   '3',
#   'x',
#   'p',
#   'd',
#   '3',
#   '3',
#   'e',
#   '4',
#   '9',
#   'j',
#   'n',
#   '2',
#   '5',
#   'j',
#   'p',
#   'h',
#   'o',
#   't',
#   '4',
#   't',
#   's',
#   'r',
#   '2'],
#  ['8',
#   'd',
#   'b',
#   'f',
#   '3',
#   'e',
#   'c',
#   'v',
#   'u',
#   'e',
#   'c',
#   'l',
#   'p',
#   'q',
#   'b',
#   'y',
#   'm',
#   'z',
#   '5',
#   'p',
#   '2',
#   'u',
#   'g',
#   't',
#   '4',
#   't',
#   'v',
#   '8',
#   'b',
#   'u',
#   'e',
#   'd'],
#  ['5',
#   'o',
#   'r',
#   'p',
#   'j',
#   '2',
#   '4',
#   's',
#   'l',
#   'f',
#   '4',
#   'j',
#   '2',
#   '6',
#   't',
#   't',
#   '0',
#   '8',
#   'n',
#   's',
#   '4',
#   '3',
#   'm',
#   'w',
#   'c',
#   '7',
#   'y',
#   'v',
#   '4',
#   '7',
#   'c',
#   'n'],
#  ['u',
#   '8',
#   'o',
#   'w',
#   'y',
#   'e',
#   '8',
#   '2',
#   'a',
#   'u',
#   'd',
#   't',
#   'w',
#   'b',
#   'c',
#   'p',
#   'h',
#   '8',
#   'v',
#   '4',
#   'a',
#   '5',
#   'j',
#   '7',
#   'o',
#   'o',
#   '8',
#   'q',
#   'q',
#   'g',
#   'm',
#   'k'],
#  ['9',
#   '9',
#   'c',
#   '0',
#   '8',
#   'o',
#   'j',
#   'j',
#   'r',
#   'l',
#   'x',
#   'p',
#   'u',
#   'm',
#   'i',
#   'z',
#   'q',
#   '4',
#   'u',
#   'z',
#   'h',
#   'm',
#   'b',
#   'e',
#   '0',
#   'a',
#   'w',
#   'v',
#   'e',
#   'r',
#   'u',
#   '6'],
#  ['l',
#   '5',
#   '5',
#   'l',
#   'n',
#   'n',
#   '3',
#   'p',
#   'd',
#   'b',
#   '8',
#   'a',
#   'n',
#   '0',
#   'q',
#   '7',
#   'c',
#   'a',
#   'q',
#   'o',
#   'w',
#   'k',
#   'z',
#   'r',
#   '3',
#   'w',
#   'b',
#   '3',
#   '4',
#   'r',
#   'i',
#   '6'],
#  ['b',
#   'g',
#   '6',
#   'f',
#   'c',
#   'k',
#   's',
#   '9',
#   '7',
#   '9',
#   'o',
#   '3',
#   'r',
#   'y',
#   't',
#   '4',
#   'f',
#   'v',
#   'q',
#   'k',
#   'z',
#   'd',
#   'm',
#   '5',
#   'g',
#   'q',
#   'u',
#   '4',
#   'm',
#   'f',
#   'e',
#   '2'],
#  ['4',
#   'w',
#   'j',
#   'l',
#   'z',
#   'v',
#   'b',
#   '4',
#   'w',
#   '4',
#   'y',
#   'h',
#   'g',
#   '8',
#   '5',
#   '2',
#   'h',
#   'l',
#   'w',
#   'o',
#   'x',
#   'x',
#   '0',
#   '2',
#   'm',
#   '2',
#   'l',
#   'c',
#   'w',
#   'a',
#   'x',
#   'v'],
#  ['e',
#   'l',
#   'c',
#   'y',
#   '4',
#   'j',
#   '8',
#   '1',
#   'w',
#   'q',
#   'y',
#   '0',
#   '9',
#   'f',
#   'y',
#   's',
#   '1',
#   'p',
#   '9',
#   'z',
#   'i',
#   'p',
#   'q',
#   'p',
#   'd',
#   'n',
#   '2',
#   't',
#   'h',
#   'o',
#   't',
#   '6'],
#  ['r',
#   'g',
#   'a',
#   'j',
#   't',
#   '4',
#   '2',
#   'h',
#   'w',
#   '1',
#   'h',
#   'k',
#   '3',
#   'a',
#   'd',
#   'm',
#   '9',
#   'r',
#   '7',
#   'x',
#   'e',
#   'm',
#   'x',
#   '9',
#   '3',
#   'x',
#   't',
#   'd',
#   '3',
#   '3',
#   '7',
#   'v'],
#  ['p',
#   'p',
#   '9',
#   '5',
#   'p',
#   '6',
#   '8',
#   'o',
#   'r',
#   'f',
#   '8',
#   'v',
#   'w',
#   'v',
#   '6',
#   'c',
#   'r',
#   'e',
#   'h',
#   'w',
#   'm',
#   '2',
#   '9',
#   'e',
#   '1',
#   '8',
#   'c',
#   '1',
#   '9',
#   'j',
#   'c',
#   'n'],
#  ['r',
#   '7',
#   't',
#   'c',
#   'w',
#   'd',
#   '1',
#   '8',
#   'b',
#   'o',
#   '2',
#   'm',
#   'b',
#   'k',
#   'j',
#   '3',
#   'u',
#   '0',
#   's',
#   'u',
#   'r',
#   '0',
#   'q',
#   'u',
#   'c',
#   'c',
#   'z',
#   '6',
#   '2',
#   'i',
#   '6',
#   'h'],
#  ['s',
#   'f',
#   'r',
#   'c',
#   'h',
#   '5',
#   '0',
#   '6',
#   'a',
#   's',
#   'a',
#   'j',
#   'p',
#   'l',
#   's',
#   'l',
#   'y',
#   '4',
#   'x',
#   '8',
#   '7',
#   'w',
#   's',
#   't',
#   'q',
#   'n',
#   '2',
#   '2',
#   '4',
#   'n',
#   '5',
#   '3'],
#  ['n',
#   '6',
#   '5',
#   'b',
#   '5',
#   'u',
#   'v',
#   '9',
#   'l',
#   'i',
#   'y',
#   'r',
#   '3',
#   's',
#   '4',
#   'k',
#   'i',
#   'd',
#   'j',
#   '5',
#   '3',
#   '8',
#   '4',
#   '7',
#   'x',
#   'r',
#   'h',
#   '1',
#   'x',
#   'd',
#   'm',
#   '5'],
#  ['q',
#   'h',
#   'e',
#   'b',
#   'c',
#   's',
#   'g',
#   'l',
#   'h',
#   '6',
#   'm',
#   '3',
#   '7',
#   '6',
#   'e',
#   'b',
#   's',
#   'y',
#   '4',
#   'p',
#   'k',
#   '1',
#   '6',
#   'a',
#   'o',
#   'a',
#   'b',
#   'f',
#   'e',
#   '9',
#   '6',
#   'q'],
#  ['i',
#   'u',
#   's',
#   'i',
#   'f',
#   'u',
#   '5',
#   'c',
#   'q',
#   'b',
#   '5',
#   'u',
#   's',
#   'd',
#   '7',
#   'o',
#   '7',
#   'p',
#   'a',
#   'e',
#   'f',
#   'r',
#   'w',
#   'k',
#   'a',
#   'p',
#   'z',
#   '9',
#   's',
#   'k',
#   'v',
#   '3'],
#  ['v',
#   'k',
#   'v',
#   '2',
#   'x',
#   'h',
#   'i',
#   'r',
#   's',
#   '0',
#   'j',
#   'u',
#   'f',
#   '3',
#   '9',
#   'v',
#   'h',
#   'g',
#   's',
#   't',
#   'c',
#   'u',
#   'g',
#   'y',
#   'n',
#   '6',
#   'e',
#   'f',
#   '7',
#   'q',
#   'p',
#   '9'],
#  ['t',
#   '8',
#   'c',
#   's',
#   'f',
#   'd',
#   'a',
#   'x',
#   'k',
#   'f',
#   'j',
#   'o',
#   'i',
#   'j',
#   'm',
#   'p',
#   'b',
#   'u',
#   '2',
#   'f',
#   'w',
#   'g',
#   '3',
#   '3',
#   'k',
#   'y',
#   '2',
#   '1',
#   'z',
#   'm',
#   'm',
#   'r'],
#  ['l',
#   'v',
#   '9',
#   '3',
#   '5',
#   'q',
#   'r',
#   'f',
#   '0',
#   'b',
#   'b',
#   'x',
#   'l',
#   'v',
#   'e',
#   'j',
#   'd',
#   'h',
#   'b',
#   '3',
#   'p',
#   '1',
#   'm',
#   'v',
#   'm',
#   '5',
#   '6',
#   'u',
#   'x',
#   'r',
#   '7',
#   'w'],
#  ['o',
#   'g',
#   'n',
#   'v',
#   'a',
#   '1',
#   'f',
#   'f',
#   'a',
#   'u',
#   '4',
#   'z',
#   '8',
#   '5',
#   '3',
#   'r',
#   '9',
#   'y',
#   '6',
#   'j',
#   'g',
#   'f',
#   '0',
#   'd',
#   'k',
#   'g',
#   'n',
#   'u',
#   '9',
#   '6',
#   'p',
#   '9'],
#  ['y',
#   'm',
#   'g',
#   'w',
#   '4',
#   'f',
#   'j',
#   'x',
#   't',
#   'c',
#   'i',
#   'l',
#   'p',
#   'e',
#   'f',
#   '7',
#   'r',
#   '0',
#   'v',
#   't',
#   'e',
#   '3',
#   '0',
#   'h',
#   's',
#   'e',
#   'f',
#   'a',
#   '7',
#   'y',
#   'h',
#   'q'],
#  ['u',
#   'i',
#   '4',
#   'w',
#   'l',
#   '9',
#   'v',
#   '8',
#   'l',
#   'h',
#   'q',
#   'i',
#   '1',
#   '7',
#   'g',
#   'j',
#   'i',
#   '6',
#   'n',
#   'd',
#   'e',
#   's',
#   'j',
#   'a',
#   'a',
#   'v',
#   'f',
#   't',
#   'k',
#   'p',
#   'z',
#   'd'],
#  ['3',
#   'p',
#   'm',
#   'r',
#   'c',
#   'l',
#   'd',
#   'l',
#   '4',
#   'j',
#   '2',
#   'x',
#   'z',
#   'a',
#   'b',
#   'r',
#   '2',
#   'c',
#   'y',
#   'a',
#   '5',
#   'd',
#   'z',
#   'r',
#   'f',
#   'i',
#   'r',
#   '7',
#   'f',
#   'l',
#   '3',
#   'i'],
#  ['p',
#   '6',
#   'a',
#   '7',
#   'h',
#   'x',
#   '2',
#   'y',
#   'w',
#   'q',
#   'o',
#   'l',
#   '6',
#   'l',
#   'x',
#   '2',
#   'e',
#   'v',
#   '0',
#   'a',
#   '6',
#   'p',
#   'g',
#   '5',
#   'j',
#   'f',
#   'c',
#   'n',
#   '7',
#   'h',
#   'k',
#   'l'],
#  ['9',
#   '1',
#   'b',
#   'd',
#   'l',
#   'p',
#   'v',
#   'q',
#   'h',
#   'm',
#   'j',
#   'p',
#   's',
#   '9',
#   'j',
#   'n',
#   '0',
#   '3',
#   'h',
#   'x',
#   '5',
#   'q',
#   'z',
#   'x',
#   'z',
#   '0',
#   'l',
#   'f',
#   '1',
#   '9',
#   'q',
#   'd'],
#  ['m',
#   '2',
#   '5',
#   '7',
#   's',
#   'k',
#   'u',
#   '9',
#   'g',
#   'w',
#   '6',
#   '3',
#   'h',
#   '0',
#   's',
#   's',
#   'n',
#   'p',
#   'y',
#   'a',
#   '3',
#   'r',
#   '6',
#   'g',
#   'o',
#   '5',
#   'b',
#   '8',
#   'n',
#   'h',
#   'u',
#   'f'],
#  ['x',
#   'o',
#   '9',
#   'y',
#   'f',
#   'c',
#   '8',
#   '9',
#   '7',
#   'u',
#   'h',
#   'a',
#   'm',
#   'z',
#   'x',
#   'u',
#   '7',
#   '8',
#   '3',
#   '6',
#   'd',
#   'i',
#   'k',
#   'z',
#   'v',
#   'r',
#   'e',
#   's',
#   's',
#   'w',
#   '4',
#   'k'],
#  ['9',
#   '6',
#   'p',
#   'e',
#   'y',
#   'k',
#   'm',
#   'l',
#   '6',
#   '9',
#   'l',
#   'z',
#   'c',
#   'm',
#   'w',
#   'k',
#   'e',
#   'r',
#   'f',
#   'd',
#   'e',
#   'i',
#   'f',
#   'e',
#   '2',
#   'q',
#   '7',
#   'p',
#   '6',
#   '3',
#   '5',
#   '4'],
#  ['2',
#   'p',
#   '2',
#   'y',
#   'c',
#   '4',
#   'b',
#   '4',
#   'u',
#   'a',
#   '8',
#   'y',
#   '1',
#   's',
#   'r',
#   '8',
#   '9',
#   '3',
#   'u',
#   'p',
#   'c',
#   'k',
#   'x',
#   'x',
#   'u',
#   'g',
#   'a',
#   'k',
#   '7',
#   '5',
#   'j',
#   'z'],
#  ['a',
#   'a',
#   'y',
#   'r',
#   'a',
#   '4',
#   'r',
#   '4',
#   '9',
#   'a',
#   '8',
#   'y',
#   'q',
#   'd',
#   '0',
#   '7',
#   'k',
#   'o',
#   'c',
#   'p',
#   'y',
#   'a',
#   'i',
#   'v',
#   '3',
#   'j',
#   's',
#   '2',
#   '0',
#   'q',
#   'l',
#   'm'],
#  ['z',
#   'w',
#   'i',
#   '8',
#   '7',
#   'h',
#   'z',
#   'b',
#   'd',
#   '4',
#   'l',
#   'r',
#   'r',
#   'v',
#   'q',
#   'g',
#   'w',
#   'b',
#   '6',
#   'q',
#   'n',
#   'w',
#   'c',
#   '2',
#   'f',
#   'b',
#   'r',
#   'r',
#   'a',
#   'k',
#   'f',
#   '6'],
#  ['c',
#   '6',
#   'j',
#   'c',
#   '4',
#   'v',
#   'c',
#   '3',
#   '4',
#   'j',
#   '3',
#   'g',
#   '4',
#   '7',
#   'i',
#   'o',
#   'c',
#   'o',
#   'a',
#   'd',
#   'h',
#   'p',
#   '1',
#   'b',
#   'h',
#   'c',
#   '1',
#   '8',
#   'v',
#   'h',
#   'q',
#   'a'],
#  ['d',
#   'p',
#   'c',
#   'o',
#   'k',
#   '6',
#   'x',
#   '3',
#   'i',
#   'q',
#   'y',
#   'b',
#   'p',
#   'h',
#   'k',
#   'm',
#   's',
#   'd',
#   'e',
#   'u',
#   '4',
#   'f',
#   '6',
#   'z',
#   'p',
#   'j',
#   'i',
#   '8',
#   '3',
#   'z',
#   '0',
#   '6'],
#  ['l',
#   'u',
#   'p',
#   'h',
#   'k',
#   'r',
#   '6',
#   'e',
#   'e',
#   'w',
#   '5',
#   '0',
#   '2',
#   's',
#   'y',
#   '8',
#   'i',
#   'u',
#   'q',
#   '0',
#   'f',
#   'b',
#   'r',
#   'n',
#   '0',
#   'v',
#   't',
#   'b',
#   'l',
#   'n',
#   '8',
#   '1'],
#  ['s',
#   'i',
#   'g',
#   'e',
#   'p',
#   't',
#   'l',
#   'g',
#   '1',
#   'l',
#   'l',
#   'o',
#   'o',
#   'a',
#   'e',
#   's',
#   '8',
#   't',
#   'x',
#   '0',
#   'a',
#   '4',
#   '1',
#   'z',
#   'i',
#   '7',
#   'v',
#   'a',
#   'h',
#   'c',
#   '3',
#   'r'],
#  ['u',
#   'r',
#   'x',
#   'v',
#   'j',
#   'l',
#   'o',
#   'h',
#   '7',
#   'f',
#   '3',
#   '4',
#   'z',
#   '7',
#   'o',
#   '3',
#   'z',
#   'k',
#   '3',
#   'm',
#   'f',
#   'b',
#   '5',
#   'm',
#   'q',
#   'a',
#   'b',
#   '8',
#   'l',
#   'a',
#   'x',
#   'm'],
#  ['e',
#   'a',
#   't',
#   'w',
#   '6',
#   '5',
#   'n',
#   'l',
#   'w',
#   'c',
#   's',
#   'p',
#   'k',
#   'a',
#   'e',
#   '9',
#   'n',
#   'x',
#   'u',
#   '2',
#   'n',
#   '3',
#   'k',
#   'i',
#   '8',
#   'r',
#   'a',
#   '9',
#   'b',
#   'p',
#   'g',
#   'i'],
#  ['u',
#   'n',
#   'm',
#   'l',
#   '2',
#   'g',
#   'u',
#   '1',
#   'g',
#   '6',
#   'l',
#   'b',
#   'v',
#   '0',
#   '6',
#   'k',
#   'e',
#   'f',
#   'v',
#   '1',
#   'z',
#   't',
#   'b',
#   'c',
#   'v',
#   's',
#   '5',
#   'v',
#   'u',
#   'w',
#   'z',
#   'z'],
#  ['j',
#   'd',
#   'e',
#   'i',
#   's',
#   'q',
#   'f',
#   's',
#   '4',
#   'l',
#   'm',
#   '8',
#   'r',
#   '4',
#   'l',
#   '6',
#   'u',
#   'e',
#   'v',
#   'y',
#   'g',
#   'v',
#   'e',
#   'n',
#   'n',
#   'c',
#   '1',
#   '9',
#   '7',
#   'g',
#   'u',
#   'g'],
#  ['0',
#   'p',
#   '8',
#   'v',
#   '8',
#   'p',
#   't',
#   'o',
#   'z',
#   'e',
#   'y',
#   '9',
#   '0',
#   'e',
#   'e',
#   'w',
#   'i',
#   'k',
#   'a',
#   'f',
#   'i',
#   'g',
#   '9',
#   'n',
#   'i',
#   '9',
#   'i',
#   'p',
#   'o',
#   'r',
#   'a',
#   'y'],
#  ['n',
#   'j',
#   'x',
#   'p',
#   '2',
#   'x',
#   '6',
#   '1',
#   't',
#   '3',
#   'y',
#   'q',
#   'q',
#   '8',
#   'x',
#   'g',
#   'c',
#   '7',
#   '5',
#   '3',
#   'k',
#   '3',
#   'k',
#   'm',
#   'b',
#   '8',
#   'h',
#   'e',
#   '8',
#   'q',
#   '1',
#   't'],
#  ['5',
#   '8',
#   'f',
#   'p',
#   '4',
#   's',
#   '4',
#   'p',
#   'k',
#   'q',
#   'f',
#   '5',
#   'z',
#   'q',
#   '2',
#   '2',
#   '5',
#   '8',
#   '0',
#   '5',
#   'a',
#   'y',
#   '2',
#   '5',
#   'g',
#   'o',
#   'p',
#   'v',
#   'g',
#   's',
#   'q',
#   '4'],
#  ['7',
#   'd',
#   'r',
#   '7',
#   'f',
#   '6',
#   'e',
#   'b',
#   'e',
#   'i',
#   '3',
#   'l',
#   'n',
#   '5',
#   'r',
#   'z',
#   'c',
#   's',
#   '1',
#   '1',
#   'i',
#   'j',
#   'h',
#   '4',
#   '5',
#   '3',
#   'c',
#   '7',
#   'l',
#   '0',
#   'q',
#   '7'],
#  ['c',
#   '8',
#   'g',
#   '3',
#   'v',
#   'x',
#   'o',
#   'v',
#   'u',
#   'v',
#   'g',
#   'e',
#   'v',
#   's',
#   'z',
#   '3',
#   'm',
#   '5',
#   '7',
#   'r',
#   'u',
#   'k',
#   'f',
#   'r',
#   'q',
#   'k',
#   'x',
#   'e',
#   '9',
#   'u',
#   'h',
#   'd'],
#  ['s',
#   'w',
#   '6',
#   'r',
#   'z',
#   'y',
#   'y',
#   'w',
#   'e',
#   'w',
#   'g',
#   'j',
#   'l',
#   '2',
#   'e',
#   '5',
#   '6',
#   'b',
#   'y',
#   'x',
#   '3',
#   'u',
#   'j',
#   '1',
#   't',
#   '0',
#   'x',
#   'f',
#   'k',
#   'd',
#   'u',
#   '9'],
#  ['f',
#   'v',
#   '3',
#   '5',
#   'j',
#   '3',
#   '5',
#   'y',
#   'b',
#   'c',
#   '5',
#   '1',
#   '4',
#   'j',
#   'i',
#   'a',
#   'f',
#   'x',
#   '4',
#   '6',
#   '8',
#   'm',
#   't',
#   'j',
#   'o',
#   '7',
#   'j',
#   'x',
#   '1',
#   'm',
#   'a',
#   '9'],
#  ['6',
#   'r',
#   'f',
#   'm',
#   'u',
#   'h',
#   'g',
#   'i',
#   '6',
#   'a',
#   '4',
#   'j',
#   'w',
#   'v',
#   'b',
#   '2',
#   '1',
#   'k',
#   '1',
#   '9',
#   'm',
#   'a',
#   'o',
#   'n',
#   '4',
#   'y',
#   'g',
#   'q',
#   'k',
#   'm',
#   't',
#   'c'],
#  ['1',
#   'd',
#   'e',
#   't',
#   'i',
#   'p',
#   'u',
#   'd',
#   'q',
#   'i',
#   '7',
#   'x',
#   'q',
#   'a',
#   'b',
#   'g',
#   'e',
#   'g',
#   'w',
#   'g',
#   'k',
#   '4',
#   '5',
#   'q',
#   'a',
#   '1',
#   'm',
#   'l',
#   'a',
#   'o',
#   '0',
#   'v'],
#  ['y',
#   'e',
#   'h',
#   't',
#   'c',
#   '6',
#   'd',
#   'z',
#   'a',
#   'n',
#   '2',
#   '8',
#   'e',
#   '7',
#   'z',
#   's',
#   '1',
#   'v',
#   'b',
#   'k',
#   's',
#   '5',
#   'k',
#   'm',
#   'i',
#   'q',
#   'f',
#   'i',
#   't',
#   'q',
#   'v',
#   'k'],
#  ['v',
#   '3',
#   'q',
#   'a',
#   't',
#   'g',
#   'm',
#   '0',
#   't',
#   '5',
#   'l',
#   'z',
#   '4',
#   'k',
#   'k',
#   'p',
#   'c',
#   '4',
#   'q',
#   'l',
#   'j',
#   'q',
#   'i',
#   'p',
#   '6',
#   'z',
#   'k',
#   't',
#   'p',
#   'w',
#   '0',
#   's'],
#  ['e',
#   '8',
#   'q',
#   'j',
#   '6',
#   '1',
#   'l',
#   'g',
#   'k',
#   'y',
#   '8',
#   'g',
#   'e',
#   'j',
#   '5',
#   '5',
#   '0',
#   't',
#   'g',
#   't',
#   '4',
#   'e',
#   't',
#   'i',
#   'w',
#   'b',
#   'v',
#   '4',
#   'v',
#   'e',
#   'u',
#   'w'],
#  ['6',
#   'e',
#   'd',
#   'v',
#   'e',
#   'l',
#   'x',
#   'l',
#   '6',
#   '2',
#   '2',
#   'h',
#   'a',
#   'n',
#   'k',
#   'p',
#   'd',
#   '3',
#   'n',
#   'n',
#   'm',
#   '8',
#   '1',
#   'y',
#   'e',
#   '0',
#   'q',
#   'f',
#   'd',
#   'a',
#   'l',
#   'w'],
#  ['7',
#   'h',
#   'o',
#   '9',
#   'h',
#   'y',
#   'g',
#   'g',
#   '2',
#   'm',
#   '0',
#   's',
#   'a',
#   'c',
#   'x',
#   '8',
#   '5',
#   'w',
#   'q',
#   'd',
#   's',
#   'p',
#   'z',
#   '1',
#   'v',
#   'j',
#   'a',
#   'w',
#   'x',
#   'o',
#   '1',
#   '4'],
#  ['p',
#   'v',
#   'l',
#   '2',
#   '8',
#   '7',
#   'c',
#   'i',
#   'h',
#   'k',
#   'w',
#   'i',
#   'v',
#   'q',
#   '0',
#   'k',
#   'm',
#   '8',
#   'i',
#   'k',
#   'm',
#   'k',
#   '3',
#   'p',
#   'k',
#   '6',
#   'm',
#   '1',
#   'o',
#   'h',
#   'c',
#   'n'],
#  ['w',
#   'n',
#   'p',
#   'd',
#   'f',
#   'd',
#   'r',
#   'o',
#   '8',
#   'h',
#   'u',
#   '5',
#   'd',
#   'h',
#   'r',
#   'e',
#   '8',
#   'u',
#   '8',
#   'q',
#   '4',
#   'r',
#   'z',
#   'f',
#   'y',
#   '6',
#   '1',
#   '4',
#   'h',
#   'e',
#   'f',
#   't'],
#  ['0',
#   'x',
#   '9',
#   '5',
#   '2',
#   'k',
#   'd',
#   'b',
#   'r',
#   'e',
#   '3',
#   '0',
#   't',
#   'f',
#   '4',
#   'w',
#   'r',
#   '1',
#   'c',
#   'b',
#   '7',
#   'u',
#   'x',
#   'x',
#   '5',
#   'r',
#   'q',
#   '0',
#   'n',
#   '2',
#   'y',
#   '7'],
#  ['j',
#   'q',
#   't',
#   's',
#   '9',
#   'h',
#   '6',
#   'h',
#   'm',
#   '0',
#   'v',
#   '0',
#   'h',
#   'm',
#   'p',
#   '5',
#   'v',
#   '0',
#   'g',
#   'c',
#   '5',
#   'z',
#   'q',
#   'h',
#   'u',
#   'z',
#   'u',
#   'z',
#   '5',
#   '5',
#   '3',
#   '6'],
#  ['c',
#   'n',
#   'w',
#   'v',
#   '2',
#   '5',
#   '3',
#   'i',
#   '6',
#   'b',
#   'l',
#   'r',
#   'l',
#   '6',
#   'n',
#   'd',
#   'd',
#   '7',
#   '3',
#   '5',
#   's',
#   '6',
#   'l',
#   '9',
#   '3',
#   '4',
#   '6',
#   'q',
#   'j',
#   'x',
#   'y',
#   '8'],
#  ['x',
#   'q',
#   'b',
#   'q',
#   'q',
#   'x',
#   'o',
#   '2',
#   'e',
#   'u',
#   'x',
#   'j',
#   'o',
#   'q',
#   'p',
#   'h',
#   'g',
#   'v',
#   'd',
#   'n',
#   'v',
#   'y',
#   'e',
#   '0',
#   '4',
#   't',
#   '2',
#   'q',
#   '3',
#   '4',
#   'y',
#   'j'],
#  ['2',
#   'x',
#   'c',
#   'g',
#   'm',
#   'v',
#   '1',
#   'b',
#   'w',
#   '2',
#   'd',
#   'v',
#   'j',
#   'e',
#   'v',
#   'm',
#   's',
#   'm',
#   '0',
#   'z',
#   'q',
#   '7',
#   'h',
#   'z',
#   'x',
#   '3',
#   'm',
#   'i',
#   '3',
#   'z',
#   '2',
#   't'],
#  ['x',
#   'v',
#   'e',
#   'y',
#   '3',
#   'm',
#   'u',
#   'm',
#   '3',
#   'l',
#   'k',
#   'm',
#   't',
#   'h',
#   'b',
#   '1',
#   's',
#   'k',
#   '2',
#   'x',
#   'g',
#   'b',
#   '5',
#   'a',
#   'g',
#   'j',
#   'j',
#   '8',
#   '1',
#   '5',
#   'z',
#   '9'],
#  ['b',
#   'd',
#   'v',
#   'i',
#   'd',
#   'x',
#   'y',
#   'y',
#   'z',
#   '2',
#   'l',
#   'l',
#   'j',
#   '7',
#   'a',
#   'b',
#   'b',
#   'g',
#   '7',
#   'e',
#   'm',
#   'l',
#   '8',
#   'p',
#   '2',
#   'e',
#   'v',
#   '1',
#   '1',
#   '5',
#   's',
#   'p'],
#  ['s',
#   'u',
#   'p',
#   'n',
#   'l',
#   'g',
#   '7',
#   '2',
#   'h',
#   'q',
#   'm',
#   'w',
#   'g',
#   '2',
#   'o',
#   'h',
#   'o',
#   'o',
#   't',
#   '9',
#   'p',
#   'l',
#   'u',
#   'c',
#   'l',
#   '1',
#   'x',
#   's',
#   'e',
#   'h',
#   'm',
#   'n'],
#  ['k',
#   'q',
#   'w',
#   'l',
#   '7',
#   'm',
#   '9',
#   'k',
#   'o',
#   's',
#   '0',
#   'k',
#   'o',
#   'z',
#   'o',
#   'y',
#   '4',
#   '6',
#   '0',
#   'r',
#   'r',
#   'g',
#   'l',
#   '1',
#   '6',
#   'e',
#   '0',
#   '7',
#   '1',
#   '0',
#   '5',
#   's'],
#  ['0',
#   '5',
#   'f',
#   '1',
#   '1',
#   '1',
#   'u',
#   'n',
#   'w',
#   's',
#   'b',
#   '4',
#   '0',
#   'j',
#   'r',
#   '5',
#   '6',
#   'd',
#   'b',
#   '8',
#   '4',
#   '0',
#   '0',
#   '5',
#   '6',
#   'e',
#   'j',
#   '1',
#   'n',
#   '9',
#   '7',
#   'i'],
#  ['j',
#   'r',
#   'j',
#   'i',
#   'l',
#   'o',
#   '5',
#   '0',
#   'k',
#   '6',
#   'c',
#   'i',
#   '2',
#   '7',
#   '4',
#   'a',
#   '1',
#   'c',
#   'l',
#   'c',
#   'b',
#   'a',
#   'g',
#   '0',
#   '6',
#   'l',
#   'x',
#   'z',
#   'h',
#   'j',
#   'e',
#   'o'],
#  ['8',
#   'a',
#   'o',
#   'a',
#   '7',
#   '4',
#   'g',
#   '9',
#   'k',
#   'w',
#   'k',
#   'f',
#   'a',
#   'p',
#   'r',
#   'a',
#   '9',
#   'z',
#   '5',
#   'g',
#   'x',
#   '5',
#   'j',
#   '7',
#   'r',
#   's',
#   'k',
#   'q',
#   'k',
#   '0',
#   'g',
#   'p'],
#  ['m',
#   '8',
#   '2',
#   's',
#   'i',
#   '9',
#   '0',
#   's',
#   '7',
#   'f',
#   'j',
#   'c',
#   'g',
#   'h',
#   '8',
#   '2',
#   'g',
#   'm',
#   '3',
#   'b',
#   '6',
#   '6',
#   'x',
#   'p',
#   'w',
#   'i',
#   'c',
#   'b',
#   '2',
#   'q',
#   'u',
#   'h'],
#  ['j',
#   '0',
#   'p',
#   'u',
#   's',
#   '2',
#   '3',
#   '1',
#   'r',
#   '2',
#   'r',
#   'm',
#   '3',
#   'b',
#   '2',
#   '3',
#   'd',
#   'q',
#   'v',
#   'e',
#   '8',
#   '7',
#   'y',
#   'k',
#   'w',
#   '9',
#   '8',
#   'l',
#   'b',
#   'y',
#   'j',
#   '0'],
#  ['t',
#   'l',
#   '5',
#   'r',
#   'l',
#   'd',
#   '3',
#   'f',
#   'z',
#   'k',
#   'm',
#   'w',
#   'x',
#   'g',
#   'm',
#   'i',
#   's',
#   'l',
#   'z',
#   'f',
#   'g',
#   's',
#   'e',
#   'r',
#   's',
#   '0',
#   'n',
#   'z',
#   'y',
#   '3',
#   'd',
#   '3'],
#  ['j',
#   'y',
#   'i',
#   'r',
#   'g',
#   'c',
#   'h',
#   'q',
#   'k',
#   'i',
#   't',
#   'd',
#   'h',
#   'd',
#   'b',
#   '1',
#   'i',
#   'd',
#   'm',
#   'l',
#   'l',
#   't',
#   '0',
#   't',
#   '1',
#   '1',
#   'm',
#   'i',
#   '0',
#   'h',
#   'o',
#   'u'],
#  ['6',
#   'x',
#   '8',
#   'e',
#   'u',
#   'e',
#   'q',
#   'l',
#   'r',
#   'b',
#   'o',
#   'c',
#   'z',
#   '6',
#   'z',
#   'j',
#   '5',
#   'f',
#   '1',
#   'q',
#   'o',
#   'z',
#   'b',
#   'c',
#   'f',
#   'w',
#   'g',
#   'q',
#   'q',
#   'l',
#   '0',
#   '1'],
#  ['9',
#   't',
#   '4',
#   'x',
#   'e',
#   'w',
#   'd',
#   'm',
#   'r',
#   's',
#   'l',
#   '6',
#   '0',
#   'w',
#   '1',
#   'c',
#   'd',
#   'f',
#   '2',
#   '9',
#   'w',
#   'q',
#   'b',
#   '3',
#   'h',
#   'x',
#   'g',
#   'v',
#   'n',
#   'b',
#   'l',
#   'k'],
#  ['n',
#   'b',
#   't',
#   'f',
#   'f',
#   'c',
#   'j',
#   'g',
#   '2',
#   '8',
#   'e',
#   'y',
#   'w',
#   'h',
#   'd',
#   'b',
#   'z',
#   'j',
#   '7',
#   'h',
#   'm',
#   'r',
#   '8',
#   '6',
#   'r',
#   '8',
#   'd',
#   '9',
#   'v',
#   'e',
#   'd',
#   'g'],
#  ['4',
#   'v',
#   '0',
#   'b',
#   '4',
#   'd',
#   'w',
#   '6',
#   '4',
#   '6',
#   '8',
#   'a',
#   '5',
#   'u',
#   'm',
#   '4',
#   'd',
#   'o',
#   'f',
#   'j',
#   '1',
#   'n',
#   '4',
#   'v',
#   'f',
#   'u',
#   '8',
#   'b',
#   'r',
#   '2',
#   '6',
#   'h'],
#  ['u',
#   'i',
#   'r',
#   'g',
#   'l',
#   'k',
#   'j',
#   '5',
#   'g',
#   'h',
#   'e',
#   'n',
#   'w',
#   'a',
#   'w',
#   'i',
#   '7',
#   'n',
#   'z',
#   'n',
#   'c',
#   'a',
#   '9',
#   's',
#   'h',
#   '9',
#   '1',
#   'h',
#   '3',
#   '5',
#   '9',
#   'l'],
#  ['1',
#   'm',
#   'a',
#   'i',
#   '7',
#   's',
#   'n',
#   'g',
#   '7',
#   'u',
#   'z',
#   'v',
#   '4',
#   'c',
#   '1',
#   '4',
#   '1',
#   's',
#   'b',
#   'o',
#   'w',
#   'n',
#   'n',
#   'm',
#   '3',
#   '0',
#   'v',
#   '4',
#   '8',
#   '7',
#   'g',
#   '4'],
#  ['5',
#   'v',
#   's',
#   'k',
#   'f',
#   'g',
#   'f',
#   'w',
#   '7',
#   'w',
#   'a',
#   'z',
#   's',
#   '3',
#   'a',
#   'k',
#   '4',
#   'f',
#   'm',
#   'o',
#   '3',
#   'x',
#   'e',
#   'i',
#   'y',
#   'h',
#   'i',
#   'k',
#   '4',
#   'u',
#   '6',
#   '5'],
#  ['5',
#   '3',
#   'z',
#   'u',
#   'a',
#   'c',
#   'u',
#   'b',
#   'j',
#   '7',
#   '1',
#   'p',
#   'j',
#   'e',
#   '9',
#   'd',
#   'm',
#   '5',
#   'm',
#   'o',
#   'a',
#   'u',
#   'p',
#   'y',
#   'f',
#   '4',
#   'p',
#   'f',
#   '2',
#   'c',
#   'r',
#   '1'],
#  ['a',
#   'a',
#   '8',
#   '0',
#   'a',
#   'f',
#   'n',
#   '6',
#   'q',
#   '1',
#   'y',
#   'g',
#   '2',
#   '5',
#   'a',
#   '6',
#   '4',
#   '3',
#   'y',
#   'g',
#   '1',
#   '9',
#   '6',
#   'p',
#   '0',
#   'v',
#   '0',
#   '8',
#   'p',
#   'c',
#   'k',
#   'v'],
#  ['3',
#   'o',
#   'n',
#   'l',
#   'u',
#   '7',
#   '7',
#   '0',
#   'r',
#   '8',
#   '0',
#   'i',
#   'b',
#   '0',
#   '9',
#   'z',
#   'e',
#   'k',
#   'l',
#   '2',
#   'h',
#   '8',
#   'q',
#   '3',
#   'n',
#   'w',
#   'f',
#   'a',
#   'u',
#   'd',
#   'n',
#   'r'],
#  ['2',
#   'w',
#   'z',
#   '4',
#   '4',
#   'f',
#   '4',
#   'v',
#   'w',
#   'q',
#   'y',
#   '4',
#   'q',
#   'l',
#   '4',
#   'e',
#   'p',
#   'e',
#   'm',
#   'g',
#   'h',
#   'y',
#   'v',
#   '2',
#   'c',
#   'm',
#   'v',
#   '7',
#   'l',
#   'f',
#   'y',
#   'u'],
#  ['7',
#   'w',
#   'd',
#   '5',
#   'k',
#   'v',
#   't',
#   'o',
#   'z',
#   'k',
#   'o',
#   'r',
#   '8',
#   'f',
#   'j',
#   'f',
#   'a',
#   'r',
#   'f',
#   '5',
#   'x',
#   '8',
#   '3',
#   'h',
#   'm',
#   'c',
#   'm',
#   'd',
#   'y',
#   '1',
#   'v',
#   's'],
#  ['f',
#   'u',
#   'h',
#   'c',
#   '9',
#   '2',
#   '8',
#   's',
#   'k',
#   'k',
#   'j',
#   'g',
#   'n',
#   'b',
#   '2',
#   'm',
#   'e',
#   'j',
#   's',
#   'y',
#   'm',
#   'i',
#   'j',
#   'g',
#   'l',
#   't',
#   'p',
#   '5',
#   'w',
#   '7',
#   'e',
#   'g'],
#  ['j',
#   'k',
#   '8',
#   'e',
#   't',
#   '2',
#   'o',
#   '5',
#   '6',
#   'b',
#   '8',
#   '5',
#   'l',
#   'q',
#   'g',
#   'h',
#   'z',
#   '2',
#   '0',
#   'e',
#   '8',
#   '8',
#   'g',
#   '0',
#   '9',
#   'l',
#   'j',
#   'z',
#   'y',
#   '4',
#   'w',
#   'd'],
#  ['x',
#   'x',
#   '8',
#   'a',
#   'f',
#   'j',
#   '6',
#   'j',
#   'a',
#   'w',
#   'f',
#   '3',
#   '0',
#   '5',
#   'd',
#   'h',
#   'h',
#   '6',
#   '7',
#   '4',
#   '0',
#   'k',
#   '8',
#   'y',
#   'v',
#   'm',
#   'y',
#   's',
#   '3',
#   '8',
#   '0',
#   'm'],
#  ['k',
#   'p',
#   '7',
#   'r',
#   'z',
#   'f',
#   'a',
#   'c',
#   '7',
#   'i',
#   's',
#   'z',
#   'g',
#   'b',
#   'p',
#   'a',
#   'i',
#   'w',
#   'k',
#   'c',
#   '1',
#   '8',
#   'p',
#   's',
#   'j',
#   '3',
#   'j',
#   'f',
#   '8',
#   '7',
#   '5',
#   'a'],
#  ['c',
#   'k',
#   'y',
#   'y',
#   'l',
#   '1',
#   'c',
#   'e',
#   '9',
#   'x',
#   'o',
#   'f',
#   'e',
#   'a',
#   '9',
#   '6',
#   'v',
#   'g',
#   's',
#   '5',
#   'p',
#   'r',
#   'w',
#   'w',
#   'n',
#   'b',
#   '4',
#   'q',
#   '1',
#   'n',
#   '1',
#   'w'],
#  ['y',
#   'e',
#   'h',
#   'o',
#   'w',
#   '3',
#   '0',
#   'a',
#   'v',
#   'l',
#   'l',
#   'f',
#   '6',
#   'f',
#   '4',
#   '7',
#   'l',
#   '8',
#   'o',
#   '1',
#   'd',
#   'v',
#   '7',
#   'y',
#   '4',
#   'h',
#   'e',
#   't',
#   'c',
#   'j',
#   '8',
#   'g'],
#  ['5',
#   'd',
#   'b',
#   'i',
#   'c',
#   'h',
#   'r',
#   'c',
#   '5',
#   'm',
#   '1',
#   'b',
#   'n',
#   'e',
#   's',
#   'z',
#   'x',
#   'k',
#   'b',
#   'z',
#   '9',
#   'x',
#   'r',
#   'e',
#   'v',
#   '0',
#   'x',
#   'b',
#   '3',
#   't',
#   'm',
#   '1'],
#  ['v',
#   'g',
#   'd',
#   'j',
#   'j',
#   '8',
#   'p',
#   '0',
#   'k',
#   '4',
#   'f',
#   'j',
#   'k',
#   'u',
#   'c',
#   'l',
#   '0',
#   't',
#   'b',
#   '7',
#   '2',
#   'c',
#   '0',
#   '1',
#   'l',
#   '3',
#   '9',
#   '4',
#   '3',
#   'x',
#   'n',
#   'b'],
#  ['r',
#   '2',
#   'r',
#   't',
#   'v',
#   'w',
#   'p',
#   'b',
#   'b',
#   'x',
#   '1',
#   'p',
#   '8',
#   'u',
#   'a',
#   'u',
#   'y',
#   'i',
#   'f',
#   'p',
#   'j',
#   's',
#   'e',
#   'p',
#   'b',
#   '6',
#   '7',
#   'g',
#   '5',
#   'h',
#   '3',
#   'x'],
#  ['4',
#   'h',
#   'm',
#   '8',
#   '7',
#   'w',
#   '7',
#   'y',
#   'a',
#   '4',
#   'j',
#   '4',
#   'e',
#   '0',
#   '8',
#   'n',
#   'p',
#   'f',
#   '1',
#   'h',
#   'a',
#   '9',
#   'n',
#   '1',
#   '5',
#   'q',
#   'd',
#   'h',
#   'r',
#   'y',
#   't',
#   'q'],
#  ['r',
#   'd',
#   '6',
#   'p',
#   'e',
#   'g',
#   'a',
#   'd',
#   'y',
#   'c',
#   'f',
#   '5',
#   '4',
#   '7',
#   'v',
#   't',
#   'x',
#   'r',
#   '4',
#   'b',
#   '5',
#   '6',
#   'k',
#   'l',
#   't',
#   'y',
#   's',
#   'c',
#   '9',
#   '0',
#   'e',
#   'c'],
#  ['t',
#   '7',
#   '9',
#   'v',
#   '4',
#   '9',
#   '8',
#   '1',
#   'p',
#   '4',
#   'b',
#   'c',
#   'a',
#   '3',
#   'u',
#   'x',
#   'e',
#   's',
#   '6',
#   '7',
#   '4',
#   'u',
#   'q',
#   'r',
#   'g',
#   'q',
#   'w',
#   '8',
#   'm',
#   'f',
#   't',
#   '6'],
#  ['d',
#   'y',
#   'z',
#   'q',
#   'p',
#   '6',
#   'g',
#   '2',
#   'y',
#   'u',
#   '0',
#   's',
#   's',
#   '9',
#   'e',
#   's',
#   'r',
#   'r',
#   'r',
#   'm',
#   'a',
#   'c',
#   '7',
#   's',
#   'x',
#   'm',
#   'o',
#   '9',
#   '3',
#   '5',
#   '2',
#   'f'],
#  ['u',
#   'm',
#   '1',
#   'x',
#   '7',
#   'v',
#   'q',
#   '7',
#   'g',
#   '3',
#   's',
#   'b',
#   'r',
#   '6',
#   'j',
#   '7',
#   '9',
#   'q',
#   'z',
#   'b',
#   '1',
#   'u',
#   'e',
#   'e',
#   '5',
#   't',
#   'c',
#   '3',
#   '9',
#   '8',
#   '3',
#   'w'],
#  ['z',
#   'q',
#   'w',
#   'b',
#   'r',
#   '9',
#   'l',
#   'v',
#   'o',
#   'o',
#   'n',
#   'w',
#   'p',
#   '2',
#   'v',
#   'f',
#   '9',
#   's',
#   'u',
#   'k',
#   'a',
#   't',
#   's',
#   'j',
#   'z',
#   '2',
#   '7',
#   'f',
#   'a',
#   'm',
#   't',
#   'b'],
#  ['c',
#   'l',
#   'p',
#   'b',
#   'e',
#   'x',
#   'i',
#   'o',
#   '0',
#   'j',
#   'x',
#   '0',
#   'd',
#   'b',
#   's',
#   'f',
#   't',
#   '6',
#   'l',
#   'z',
#   'e',
#   '4',
#   'c',
#   'h',
#   'g',
#   'w',
#   '5',
#   'p',
#   'a',
#   '7',
#   'a',
#   'm'],
#  ['x',
#   'c',
#   'y',
#   'p',
#   'a',
#   'm',
#   'n',
#   '6',
#   'x',
#   'o',
#   'e',
#   'a',
#   's',
#   '9',
#   'a',
#   'u',
#   '9',
#   'z',
#   'b',
#   'e',
#   'j',
#   'd',
#   '3',
#   't',
#   'o',
#   '1',
#   'e',
#   'v',
#   'c',
#   'j',
#   's',
#   'd'],
#  ['w',
#   'f',
#   'b',
#   'j',
#   'g',
#   'h',
#   's',
#   'b',
#   'e',
#   '9',
#   't',
#   'z',
#   '9',
#   't',
#   'd',
#   'h',
#   'q',
#   '3',
#   'p',
#   'n',
#   'z',
#   'u',
#   'n',
#   '9',
#   'r',
#   '1',
#   'e',
#   'v',
#   '9',
#   'z',
#   'x',
#   '9'],
#  ['3',
#   'v',
#   'r',
#   'd',
#   'i',
#   'q',
#   'u',
#   'p',
#   'b',
#   'z',
#   'p',
#   'w',
#   'i',
#   '3',
#   '9',
#   'w',
#   '8',
#   '9',
#   '6',
#   'h',
#   'm',
#   'z',
#   '9',
#   '0',
#   '4',
#   'p',
#   'j',
#   'j',
#   'h',
#   'z',
#   's',
#   '1'],
#  ['f',
#   'q',
#   'd',
#   '9',
#   'l',
#   'g',
#   'l',
#   'f',
#   'a',
#   'm',
#   'g',
#   'g',
#   'l',
#   's',
#   'z',
#   'o',
#   'a',
#   '4',
#   'a',
#   'r',
#   'm',
#   'u',
#   'p',
#   'x',
#   '7',
#   '5',
#   'w',
#   'j',
#   'x',
#   '8',
#   'h',
#   'k'],
#  ['j',
#   'c',
#   'v',
#   'l',
#   'q',
#   'w',
#   '1',
#   'k',
#   'g',
#   't',
#   '0',
#   '6',
#   'k',
#   'm',
#   'a',
#   'u',
#   'w',
#   't',
#   'j',
#   'h',
#   'g',
#   'n',
#   'a',
#   '4',
#   'm',
#   'u',
#   'h',
#   '0',
#   '7',
#   'y',
#   'x',
#   'j'],
#  ['2',
#   's',
#   '7',
#   'd',
#   'm',
#   '4',
#   'p',
#   'r',
#   'd',
#   'g',
#   'f',
#   '5',
#   '3',
#   '1',
#   'm',
#   'k',
#   '2',
#   'x',
#   '7',
#   'y',
#   'k',
#   's',
#   'p',
#   '8',
#   'w',
#   'k',
#   'h',
#   'i',
#   '4',
#   '6',
#   'y',
#   'k'],
#  ['f',
#   'm',
#   '6',
#   'h',
#   'p',
#   'm',
#   '3',
#   'b',
#   'u',
#   'y',
#   '5',
#   '4',
#   'f',
#   '7',
#   'e',
#   'k',
#   '0',
#   'u',
#   'a',
#   '2',
#   'k',
#   '0',
#   'o',
#   'n',
#   'r',
#   'l',
#   '7',
#   'a',
#   'r',
#   '5',
#   'd',
#   '6'],
#  ['6',
#   'w',
#   't',
#   'w',
#   'k',
#   's',
#   'y',
#   'k',
#   'j',
#   'q',
#   'o',
#   'y',
#   '8',
#   'h',
#   '2',
#   'r',
#   '1',
#   'f',
#   'q',
#   'u',
#   'a',
#   'x',
#   'x',
#   '3',
#   'w',
#   'q',
#   'u',
#   'y',
#   'g',
#   'm',
#   'u',
#   'z'],
#  ['j',
#   'c',
#   '5',
#   'e',
#   '5',
#   'x',
#   'p',
#   't',
#   'h',
#   '4',
#   's',
#   '7',
#   '1',
#   '0',
#   'z',
#   't',
#   'i',
#   '8',
#   'm',
#   'f',
#   '3',
#   'b',
#   '0',
#   'b',
#   'x',
#   'd',
#   'l',
#   'g',
#   'm',
#   'p',
#   'b',
#   '7'],
#  ['3',
#   'd',
#   'p',
#   'm',
#   '8',
#   'b',
#   'k',
#   'j',
#   'q',
#   'r',
#   '7',
#   '7',
#   'u',
#   'i',
#   'l',
#   'y',
#   '3',
#   'k',
#   'n',
#   'u',
#   '4',
#   'z',
#   'z',
#   '3',
#   '7',
#   'a',
#   'q',
#   'v',
#   'x',
#   '5',
#   'o',
#   'q'],
#  ['g',
#   'n',
#   'r',
#   '1',
#   'w',
#   '1',
#   'w',
#   'r',
#   'f',
#   'j',
#   '5',
#   'e',
#   '6',
#   'c',
#   '1',
#   'u',
#   's',
#   'j',
#   'd',
#   'm',
#   'b',
#   'p',
#   'v',
#   '4',
#   '5',
#   'p',
#   't',
#   'j',
#   'i',
#   'u',
#   'u',
#   '6'],
#  ['h',
#   'l',
#   '7',
#   'y',
#   'j',
#   'b',
#   's',
#   '1',
#   'y',
#   '6',
#   'l',
#   'e',
#   '4',
#   '9',
#   'y',
#   'n',
#   'u',
#   'e',
#   'a',
#   'a',
#   'i',
#   '1',
#   'j',
#   '1',
#   'y',
#   'h',
#   'a',
#   '2',
#   'l',
#   '7',
#   'k',
#   't'],
#  ['4',
#   'b',
#   '8',
#   '6',
#   'v',
#   '5',
#   '6',
#   'l',
#   'x',
#   'g',
#   'w',
#   '9',
#   '7',
#   'u',
#   'j',
#   'n',
#   'c',
#   'c',
#   'y',
#   's',
#   'r',
#   'x',
#   'f',
#   'z',
#   'n',
#   '8',
#   'r',
#   't',
#   '7',
#   'a',
#   '2',
#   '2'],
#  ['0',
#   'l',
#   '7',
#   'i',
#   'x',
#   '3',
#   'l',
#   'l',
#   'u',
#   'i',
#   '7',
#   'h',
#   '2',
#   '4',
#   'y',
#   '0',
#   '3',
#   '7',
#   'a',
#   '7',
#   's',
#   'c',
#   '0',
#   'b',
#   'y',
#   'o',
#   'k',
#   'm',
#   '4',
#   '6',
#   'z',
#   '7'],
#  ['j',
#   'b',
#   'k',
#   'n',
#   'm',
#   'e',
#   'n',
#   'e',
#   'e',
#   'i',
#   '8',
#   'u',
#   '7',
#   'i',
#   'k',
#   '1',
#   '1',
#   'm',
#   'm',
#   '0',
#   'b',
#   'b',
#   'w',
#   't',
#   'e',
#   '8',
#   'z',
#   'b',
#   'h',
#   '0',
#   '2',
#   'i'],
#  ['d',
#   'z',
#   'z',
#   'w',
#   '2',
#   'v',
#   '9',
#   'u',
#   's',
#   '0',
#   'j',
#   't',
#   'n',
#   'n',
#   'i',
#   'o',
#   '8',
#   'y',
#   'f',
#   'c',
#   'p',
#   'b',
#   'p',
#   'n',
#   'i',
#   'h',
#   '7',
#   '1',
#   '4',
#   'd',
#   'l',
#   'p'],
#  ['b',
#   'p',
#   '8',
#   'f',
#   '5',
#   'b',
#   'x',
#   'r',
#   'g',
#   'n',
#   '0',
#   'l',
#   't',
#   'a',
#   'i',
#   'q',
#   'f',
#   'h',
#   '6',
#   'o',
#   'q',
#   'a',
#   'w',
#   'j',
#   'a',
#   'j',
#   'q',
#   'c',
#   '5',
#   '2',
#   'z',
#   'k'],
#  ['e',
#   'p',
#   'u',
#   'j',
#   'y',
#   'w',
#   '7',
#   '6',
#   '8',
#   'i',
#   'j',
#   'i',
#   'l',
#   'o',
#   'e',
#   '4',
#   'e',
#   'e',
#   'v',
#   'x',
#   'f',
#   'v',
#   'u',
#   '0',
#   'u',
#   'j',
#   'y',
#   'j',
#   'r',
#   'l',
#   's',
#   'n'],
#  ['1',
#   '8',
#   'e',
#   'z',
#   '9',
#   'z',
#   'c',
#   'g',
#   'i',
#   'm',
#   'a',
#   '6',
#   's',
#   '8',
#   '2',
#   '8',
#   'c',
#   'c',
#   'i',
#   'b',
#   'z',
#   '9',
#   '6',
#   'i',
#   's',
#   'z',
#   'w',
#   '0',
#   '1',
#   '1',
#   '2',
#   't'],
#  ['3',
#   'c',
#   'm',
#   'v',
#   'y',
#   '9',
#   'n',
#   'e',
#   'm',
#   '3',
#   'p',
#   'e',
#   '6',
#   'h',
#   'c',
#   '5',
#   'j',
#   'h',
#   'm',
#   'e',
#   'v',
#   'r',
#   'i',
#   'c',
#   '2',
#   'j',
#   'k',
#   'p',
#   'i',
#   'z',
#   'o',
#   '7'],
#  ['n',
#   '5',
#   '4',
#   'w',
#   'p',
#   's',
#   'd',
#   'k',
#   '0',
#   'y',
#   'h',
#   '8',
#   '8',
#   '2',
#   'o',
#   'c',
#   'j',
#   'p',
#   '3',
#   's',
#   '8',
#   '1',
#   '1',
#   'o',
#   'a',
#   'n',
#   'f',
#   'o',
#   'a',
#   'y',
#   'f',
#   'r'],
#  ['o',
#   'f',
#   't',
#   'e',
#   'v',
#   '7',
#   '9',
#   '1',
#   '1',
#   'a',
#   'l',
#   '1',
#   'k',
#   'l',
#   'u',
#   'q',
#   'z',
#   '7',
#   'i',
#   '6',
#   '2',
#   '3',
#   'h',
#   'v',
#   '4',
#   'x',
#   'n',
#   'r',
#   '4',
#   'o',
#   'e',
#   'j'],
#  ['v',
#   'n',
#   '1',
#   'g',
#   'i',
#   'h',
#   'n',
#   'u',
#   'u',
#   'f',
#   's',
#   '1',
#   'e',
#   'r',
#   'w',
#   'u',
#   '1',
#   's',
#   '8',
#   '3',
#   '6',
#   'd',
#   'b',
#   '2',
#   'm',
#   'o',
#   's',
#   '1',
#   '0',
#   't',
#   'a',
#   'q'],
#  ['x',
#   'q',
#   'x',
#   'm',
#   'n',
#   'i',
#   'r',
#   '1',
#   '1',
#   '8',
#   'i',
#   'r',
#   '9',
#   'q',
#   '2',
#   'b',
#   '3',
#   'w',
#   'm',
#   '1',
#   'x',
#   'p',
#   '9',
#   'x',
#   '3',
#   'c',
#   '7',
#   'q',
#   'q',
#   'w',
#   'u',
#   'f'],
#  ['t',
#   'v',
#   'v',
#   'b',
#   '6',
#   'b',
#   '0',
#   'h',
#   'f',
#   'p',
#   '1',
#   't',
#   'o',
#   'a',
#   '8',
#   'n',
#   '6',
#   '3',
#   'a',
#   'r',
#   'e',
#   '6',
#   'i',
#   'q',
#   'o',
#   '2',
#   'k',
#   'g',
#   'o',
#   '6',
#   '8',
#   '4'],
#  ['7',
#   'r',
#   'u',
#   'r',
#   'd',
#   't',
#   'w',
#   'z',
#   'w',
#   'w',
#   'k',
#   'h',
#   'x',
#   'a',
#   'z',
#   'j',
#   'l',
#   '0',
#   'h',
#   'a',
#   's',
#   'y',
#   'k',
#   '0',
#   '0',
#   'i',
#   '7',
#   'c',
#   '0',
#   's',
#   'i',
#   't'],
#  ['q',
#   'x',
#   't',
#   't',
#   '6',
#   'r',
#   'a',
#   '5',
#   'b',
#   '7',
#   'p',
#   'w',
#   'w',
#   'e',
#   '6',
#   'n',
#   '9',
#   '1',
#   '9',
#   'x',
#   '0',
#   'f',
#   'e',
#   'h',
#   'l',
#   'b',
#   'w',
#   'm',
#   'k',
#   'q',
#   't',
#   'q'],
#  ['7',
#   's',
#   'q',
#   'a',
#   '6',
#   '7',
#   '7',
#   'p',
#   'f',
#   '4',
#   '6',
#   'f',
#   '2',
#   '8',
#   '6',
#   'a',
#   's',
#   '7',
#   'y',
#   'b',
#   't',
#   's',
#   'j',
#   'o',
#   'g',
#   'c',
#   '4',
#   'y',
#   't',
#   'y',
#   'y',
#   '0'],
#  ['7',
#   'n',
#   '1',
#   '0',
#   'm',
#   '2',
#   'x',
#   't',
#   'f',
#   'i',
#   '7',
#   'v',
#   'j',
#   '5',
#   't',
#   'b',
#   'q',
#   'v',
#   'e',
#   'd',
#   'v',
#   'i',
#   'p',
#   'k',
#   'a',
#   '2',
#   'p',
#   'r',
#   'u',
#   'j',
#   'p',
#   'f'],
#  ['m',
#   '5',
#   'm',
#   '6',
#   'l',
#   '1',
#   'q',
#   'u',
#   'k',
#   '4',
#   'a',
#   'q',
#   'x',
#   'd',
#   'c',
#   'j',
#   'k',
#   '1',
#   'j',
#   'j',
#   'h',
#   'a',
#   'l',
#   'z',
#   '8',
#   '6',
#   'i',
#   '9',
#   'b',
#   'z',
#   'g',
#   'j'],
#  ['s',
#   'c',
#   'p',
#   'z',
#   '3',
#   '1',
#   'g',
#   'd',
#   '3',
#   '2',
#   'r',
#   '9',
#   's',
#   '6',
#   '7',
#   't',
#   'u',
#   'd',
#   'k',
#   'y',
#   '2',
#   'h',
#   'z',
#   'l',
#   'f',
#   'p',
#   '5',
#   'p',
#   'n',
#   'u',
#   'g',
#   '4'],
#  ['o',
#   '8',
#   '0',
#   'o',
#   'l',
#   'x',
#   'o',
#   '0',
#   'v',
#   'a',
#   'w',
#   '0',
#   'r',
#   'c',
#   'm',
#   'g',
#   'o',
#   '1',
#   '1',
#   'f',
#   'e',
#   '4',
#   '5',
#   'x',
#   '4',
#   'm',
#   'x',
#   'e',
#   '5',
#   'p',
#   '4',
#   '7'],
#  ['o',
#   'i',
#   'd',
#   'r',
#   'e',
#   'f',
#   's',
#   's',
#   '9',
#   '2',
#   '0',
#   'e',
#   'k',
#   '0',
#   '5',
#   'c',
#   'u',
#   'v',
#   '8',
#   'm',
#   'm',
#   'n',
#   'q',
#   'r',
#   'n',
#   'q',
#   'g',
#   'r',
#   'g',
#   'm',
#   'k',
#   'q'],
#  ['1',
#   'j',
#   'x',
#   '7',
#   '8',
#   '9',
#   'm',
#   '3',
#   'b',
#   '5',
#   'f',
#   'q',
#   '8',
#   '8',
#   '1',
#   'b',
#   'z',
#   '7',
#   '5',
#   'l',
#   'i',
#   'w',
#   'a',
#   'h',
#   '8',
#   't',
#   'i',
#   'n',
#   'v',
#   'j',
#   'i',
#   'i'],
#  ['9',
#   'n',
#   '7',
#   'b',
#   '2',
#   '2',
#   'd',
#   'x',
#   'z',
#   '2',
#   'd',
#   'r',
#   'f',
#   'x',
#   'y',
#   'i',
#   'i',
#   'g',
#   'u',
#   'y',
#   'a',
#   's',
#   'b',
#   '3',
#   '8',
#   'c',
#   '5',
#   '8',
#   '3',
#   'r',
#   'q',
#   'w'],
#  ['g',
#   'u',
#   'h',
#   '0',
#   'k',
#   'j',
#   'o',
#   '0',
#   '8',
#   'j',
#   'l',
#   '0',
#   'w',
#   '3',
#   'k',
#   '6',
#   'i',
#   'x',
#   's',
#   '9',
#   '0',
#   'l',
#   '4',
#   '3',
#   'u',
#   'c',
#   'e',
#   '1',
#   'i',
#   '5',
#   'b',
#   '3'],
#  ['y',
#   'b',
#   'f',
#   'n',
#   'd',
#   '3',
#   'd',
#   'z',
#   '5',
#   't',
#   'd',
#   'e',
#   'e',
#   'j',
#   '5',
#   'b',
#   '0',
#   'i',
#   'f',
#   'w',
#   '2',
#   'g',
#   'w',
#   'c',
#   'e',
#   'x',
#   'm',
#   'v',
#   't',
#   'q',
#   'x',
#   'o'],
#  ['x',
#   '5',
#   'd',
#   'a',
#   '1',
#   'b',
#   'f',
#   's',
#   '4',
#   'w',
#   'm',
#   'y',
#   'r',
#   'y',
#   '3',
#   'k',
#   'x',
#   'a',
#   's',
#   'j',
#   'r',
#   'q',
#   'b',
#   'h',
#   'n',
#   'u',
#   'i',
#   'u',
#   'o',
#   'l',
#   'g',
#   'x'],
#  ['s',
#   'f',
#   'u',
#   '6',
#   'x',
#   'p',
#   'm',
#   'k',
#   '7',
#   '6',
#   'e',
#   'y',
#   'a',
#   'f',
#   'a',
#   'd',
#   '9',
#   'l',
#   'q',
#   'l',
#   'y',
#   'f',
#   '5',
#   'u',
#   'p',
#   'a',
#   'i',
#   'q',
#   '2',
#   'u',
#   '2',
#   'f'],
#  ['q',
#   '9',
#   'i',
#   'n',
#   '9',
#   'e',
#   'w',
#   'o',
#   '5',
#   's',
#   '0',
#   '3',
#   '7',
#   'l',
#   'x',
#   'n',
#   'v',
#   'b',
#   '0',
#   'w',
#   'a',
#   '7',
#   '8',
#   'r',
#   'w',
#   '8',
#   '0',
#   'y',
#   'g',
#   'b',
#   'u',
#   's'],
#  ['9',
#   '9',
#   'o',
#   'k',
#   '1',
#   'y',
#   'k',
#   'k',
#   'o',
#   'f',
#   'm',
#   'i',
#   'c',
#   'y',
#   'r',
#   'u',
#   '3',
#   'r',
#   'j',
#   'b',
#   'q',
#   '8',
#   '5',
#   'v',
#   'o',
#   '8',
#   '0',
#   'o',
#   'v',
#   'j',
#   's',
#   '2'],
#  ['x',
#   'd',
#   'a',
#   'v',
#   'v',
#   '9',
#   'v',
#   '5',
#   '3',
#   'c',
#   'c',
#   '7',
#   'o',
#   'o',
#   's',
#   'u',
#   'n',
#   'c',
#   'b',
#   'i',
#   'o',
#   'h',
#   '5',
#   '1',
#   'q',
#   '2',
#   '3',
#   'f',
#   '7',
#   't',
#   '3',
#   'u'],
#  ['8',
#   'm',
#   'y',
#   'd',
#   'o',
#   '3',
#   '7',
#   'b',
#   'q',
#   '9',
#   'u',
#   'm',
#   'x',
#   'd',
#   'g',
#   '7',
#   'o',
#   'm',
#   'w',
#   '3',
#   'a',
#   '0',
#   '0',
#   '3',
#   '9',
#   'p',
#   'i',
#   '7',
#   'w',
#   'p',
#   'z',
#   '2'],
#  ['x',
#   'e',
#   '9',
#   '1',
#   'l',
#   '8',
#   'j',
#   'o',
#   '3',
#   'k',
#   'p',
#   'x',
#   '6',
#   'n',
#   'x',
#   'n',
#   'p',
#   '5',
#   'l',
#   'd',
#   'a',
#   'c',
#   'i',
#   'k',
#   'o',
#   'j',
#   '4',
#   't',
#   '5',
#   'c',
#   'w',
#   'p'],
#  ['e',
#   'j',
#   'i',
#   'o',
#   'v',
#   'q',
#   'c',
#   'i',
#   'z',
#   'u',
#   't',
#   '6',
#   'w',
#   '5',
#   '4',
#   'b',
#   'j',
#   't',
#   '4',
#   'b',
#   'o',
#   'h',
#   'l',
#   'b',
#   'p',
#   'q',
#   'l',
#   '5',
#   'p',
#   'q',
#   'l',
#   'r'],
#  ['c',
#   'f',
#   'w',
#   'q',
#   'm',
#   '9',
#   'l',
#   '8',
#   'i',
#   'a',
#   's',
#   'a',
#   'i',
#   'y',
#   'q',
#   'a',
#   'f',
#   's',
#   'r',
#   'm',
#   'f',
#   's',
#   '8',
#   's',
#   '6',
#   '1',
#   '2',
#   'y',
#   'g',
#   'c',
#   'k',
#   'j'],
#  ['y',
#   'l',
#   'a',
#   '8',
#   'h',
#   't',
#   'n',
#   '8',
#   '7',
#   '6',
#   'a',
#   'm',
#   '7',
#   'p',
#   'h',
#   '2',
#   '8',
#   '2',
#   'h',
#   'h',
#   'p',
#   '8',
#   'c',
#   'm',
#   '8',
#   'c',
#   'b',
#   'g',
#   'g',
#   '8',
#   'd',
#   'n'],
#  ['b',
#   '8',
#   'v',
#   'k',
#   'j',
#   'l',
#   'r',
#   '4',
#   'q',
#   '8',
#   '7',
#   'e',
#   'x',
#   'b',
#   '9',
#   'w',
#   'p',
#   'w',
#   'x',
#   '3',
#   'i',
#   'a',
#   'q',
#   'g',
#   'm',
#   '2',
#   'g',
#   's',
#   'c',
#   '9',
#   'f',
#   'b'],
#  ['c',
#   '8',
#   '9',
#   'w',
#   '8',
#   'n',
#   '9',
#   'o',
#   '5',
#   '1',
#   'k',
#   'e',
#   '9',
#   'm',
#   'o',
#   'b',
#   '2',
#   'l',
#   'f',
#   'y',
#   'e',
#   'l',
#   'q',
#   'l',
#   '3',
#   'l',
#   'k',
#   'k',
#   '0',
#   'j',
#   '4',
#   '5'],
#  ['2',
#   'c',
#   '5',
#   'j',
#   'h',
#   't',
#   't',
#   'p',
#   'i',
#   'c',
#   'm',
#   's',
#   'b',
#   'x',
#   'b',
#   'n',
#   'g',
#   'a',
#   '5',
#   'l',
#   'v',
#   '0',
#   'w',
#   'l',
#   'x',
#   'v',
#   's',
#   'g',
#   'j',
#   'w',
#   'h',
#   '0'],
#  ['k',
#   'm',
#   'k',
#   'b',
#   'j',
#   'n',
#   '6',
#   'y',
#   '3',
#   'z',
#   'o',
#   '3',
#   '9',
#   'l',
#   '9',
#   'm',
#   'p',
#   'h',
#   'y',
#   'o',
#   'j',
#   't',
#   'q',
#   '8',
#   'j',
#   '0',
#   '2',
#   'v',
#   '0',
#   't',
#   'i',
#   '5'],
#  ['9',
#   'x',
#   'a',
#   'i',
#   'e',
#   's',
#   '0',
#   '6',
#   'b',
#   'g',
#   'z',
#   '0',
#   'j',
#   '2',
#   'j',
#   'd',
#   '9',
#   'o',
#   'o',
#   '9',
#   '8',
#   't',
#   '3',
#   'v',
#   'c',
#   'h',
#   'g',
#   'n',
#   '9',
#   'i',
#   'm',
#   '1'],
#  ['z',
#   't',
#   't',
#   'q',
#   'b',
#   'g',
#   'k',
#   'w',
#   'i',
#   'm',
#   'd',
#   '6',
#   'y',
#   'v',
#   'a',
#   '3',
#   'w',
#   'c',
#   'i',
#   't',
#   'v',
#   'y',
#   'r',
#   'f',
#   'c',
#   'q',
#   '3',
#   't',
#   'a',
#   '2',
#   'v',
#   't'],
#  ['a',
#   'z',
#   't',
#   'b',
#   'v',
#   'b',
#   '4',
#   '4',
#   'i',
#   'a',
#   'p',
#   'p',
#   'j',
#   'x',
#   'z',
#   '7',
#   'q',
#   'b',
#   '0',
#   'f',
#   'd',
#   'v',
#   'f',
#   'd',
#   'm',
#   's',
#   'q',
#   '3',
#   '9',
#   '6',
#   'm',
#   'z'],
#  ['m',
#   '8',
#   'w',
#   'u',
#   'a',
#   'h',
#   '3',
#   'q',
#   '0',
#   '4',
#   'w',
#   'x',
#   '6',
#   'z',
#   'v',
#   'v',
#   'f',
#   'f',
#   'h',
#   'q',
#   'e',
#   'r',
#   'a',
#   '5',
#   '4',
#   'b',
#   '8',
#   'l',
#   'u',
#   'i',
#   'o',
#   'c'],
#  ['1',
#   '2',
#   'u',
#   '8',
#   '6',
#   'q',
#   '7',
#   'q',
#   'm',
#   '3',
#   'h',
#   'l',
#   '6',
#   'v',
#   'a',
#   'd',
#   'q',
#   'd',
#   '8',
#   'f',
#   '9',
#   'x',
#   'w',
#   'y',
#   '8',
#   'b',
#   'l',
#   'v',
#   'd',
#   'p',
#   't',
#   'g'],
#  ['9',
#   '5',
#   'b',
#   'd',
#   'b',
#   'g',
#   'p',
#   'z',
#   's',
#   'l',
#   '0',
#   '4',
#   'v',
#   'd',
#   '2',
#   '0',
#   'g',
#   'v',
#   '8',
#   '5',
#   'w',
#   'h',
#   '8',
#   'p',
#   'm',
#   't',
#   'p',
#   'd',
#   '8',
#   'a',
#   'b',
#   '6'],
#  ['4',
#   'p',
#   'd',
#   '5',
#   'v',
#   'n',
#   'y',
#   'y',
#   '2',
#   'e',
#   'b',
#   'm',
#   'd',
#   'k',
#   '5',
#   'v',
#   'h',
#   '8',
#   'p',
#   'l',
#   'd',
#   'q',
#   'y',
#   't',
#   'h',
#   'd',
#   'c',
#   'c',
#   'r',
#   'j',
#   '0',
#   'i'],
#  ['9',
#   'p',
#   'i',
#   'x',
#   'p',
#   'i',
#   '9',
#   'u',
#   'a',
#   's',
#   'j',
#   'g',
#   'k',
#   'p',
#   't',
#   '7',
#   'i',
#   'g',
#   'c',
#   '6',
#   'j',
#   'e',
#   'f',
#   'k',
#   'm',
#   'k',
#   '6',
#   '8',
#   's',
#   'u',
#   '2',
#   'q'],
#  ['b',
#   'h',
#   'w',
#   'b',
#   '7',
#   'd',
#   'h',
#   't',
#   '4',
#   '9',
#   'x',
#   '5',
#   'e',
#   'l',
#   'g',
#   '6',
#   'h',
#   'y',
#   't',
#   '2',
#   '9',
#   'd',
#   'l',
#   '4',
#   'z',
#   'a',
#   'r',
#   'v',
#   'x',
#   '7',
#   'u',
#   'p'],
#  ['6',
#   'u',
#   'g',
#   's',
#   '6',
#   'l',
#   'i',
#   'k',
#   'd',
#   'z',
#   'o',
#   'k',
#   '8',
#   'j',
#   'y',
#   'b',
#   'p',
#   'f',
#   '0',
#   'm',
#   's',
#   '9',
#   'd',
#   'p',
#   'b',
#   'u',
#   '0',
#   'e',
#   'p',
#   'a',
#   '5',
#   'm'],
#  ['d',
#   't',
#   'w',
#   '0',
#   'z',
#   'e',
#   'd',
#   'b',
#   'k',
#   '8',
#   '7',
#   'z',
#   'u',
#   'o',
#   '0',
#   'd',
#   'z',
#   'w',
#   'z',
#   'i',
#   'm',
#   '7',
#   '0',
#   '6',
#   'w',
#   'b',
#   'c',
#   'r',
#   '0',
#   '9',
#   '5',
#   'f'],
#  ['d',
#   'e',
#   '5',
#   'y',
#   'r',
#   'q',
#   'f',
#   'f',
#   'u',
#   'n',
#   'b',
#   'p',
#   'e',
#   'g',
#   'n',
#   'v',
#   'z',
#   '0',
#   '7',
#   'd',
#   'u',
#   'z',
#   '5',
#   'i',
#   'b',
#   '6',
#   'j',
#   'b',
#   'g',
#   '2',
#   'f',
#   'z'],
#  ['v',
#   'o',
#   'l',
#   '4',
#   'h',
#   'e',
#   'm',
#   'm',
#   'y',
#   '2',
#   'd',
#   'z',
#   'u',
#   'u',
#   'f',
#   'q',
#   's',
#   'u',
#   'o',
#   'y',
#   '8',
#   'g',
#   'b',
#   'f',
#   '1',
#   'c',
#   'c',
#   'h',
#   'v',
#   'u',
#   'u',
#   'x'],
#  ['4',
#   'd',
#   'h',
#   'j',
#   'p',
#   'b',
#   '0',
#   'a',
#   'o',
#   'c',
#   'm',
#   '3',
#   'u',
#   'f',
#   '6',
#   'x',
#   '5',
#   'h',
#   'g',
#   '8',
#   'g',
#   '1',
#   'v',
#   'p',
#   '4',
#   't',
#   'f',
#   '2',
#   'n',
#   'y',
#   'w',
#   '0'],
#  ['5',
#   'm',
#   'w',
#   'l',
#   'b',
#   'h',
#   'u',
#   'r',
#   'f',
#   's',
#   'j',
#   'c',
#   '6',
#   'm',
#   '3',
#   '7',
#   'r',
#   'y',
#   'd',
#   'h',
#   '3',
#   'o',
#   'h',
#   'c',
#   'h',
#   'i',
#   'q',
#   't',
#   '2',
#   'u',
#   'y',
#   'c'],
#  ['l',
#   'b',
#   '9',
#   'w',
#   '7',
#   'y',
#   '3',
#   'w',
#   'u',
#   'i',
#   'q',
#   '0',
#   '8',
#   'q',
#   'o',
#   '1',
#   '1',
#   'g',
#   '5',
#   '2',
#   'm',
#   'k',
#   'l',
#   'o',
#   'u',
#   '8',
#   'a',
#   'c',
#   '5',
#   'b',
#   '3',
#   '8'],
#  ['k',
#   '3',
#   'o',
#   'z',
#   '5',
#   's',
#   'n',
#   'i',
#   'f',
#   'e',
#   '4',
#   'p',
#   'k',
#   '7',
#   '0',
#   '1',
#   'r',
#   'h',
#   'g',
#   'm',
#   'n',
#   'o',
#   'l',
#   'b',
#   '4',
#   'x',
#   'f',
#   'g',
#   'g',
#   'd',
#   '6',
#   'z'],
#  ['v',
#   'y',
#   'h',
#   'v',
#   'c',
#   'v',
#   '3',
#   's',
#   'm',
#   '4',
#   'o',
#   'q',
#   'l',
#   'x',
#   '6',
#   'g',
#   'w',
#   '3',
#   '7',
#   'y',
#   '2',
#   '1',
#   'u',
#   'n',
#   '8',
#   '3',
#   'w',
#   'j',
#   't',
#   'u',
#   'l',
#   '8']]

# %%
# def fitness(population):
#     fitness_scores = []
#     for chromosome in population:
#         matches = 0
#         for index in range(passcode_length):
#             if secret_passcode[index] == chromosome[index]:
#                 matches += 1
#         result = [chromosome,matches]
#         fitness_scores.append(result)
# #         print(fitness_scores)
#     return fitness_scores

def fitness(population):
    fitness_scores = []
    for chromosome in population:
        matches = 0
        str_chromosome = "".join(chromosome)
        matches_percentage = blurry_memory([str_chromosome],190573735,0)[str_chromosome]
        match = int(matches_percentage*10)        
        result = [chromosome,match]
        fitness_scores.append(result)
    return fitness_scores

# %%
def select_parents(fitness_scores):
    parents_list = []
    for chromosome in sorted(fitness_scores, key=lambda x: x[1], reverse = True)[:num_parents]:
        parents_list.append(chromosome[0])
    return(parents_list)

# %%
# breeding logic
def breed(parent1,parent2):
    child = []

    parent1 = parents[0]
    parent2 = parents[1]

    geneA = int(random.random() * passcode_length)
    geneB = int(random.random() * passcode_length)

    startGene = min(geneA, geneB)
    endGene = max(geneA, geneB)

    for i in range(0,passcode_length):
        if (i < startGene) or (i > endGene):
            child.append(parent1[i])
        else:
            child.append(parent2[i])
    return child

# breeding and elitism
def create_children(parents_pool):
    children = []
    num_new_children = len(population) - elite_size

    for i in range(0,elite_size):
        children.append(parents_pool[i])

    for i in range(0,num_new_children):
        parent1 = parents_pool[int(random.random() * len(parents_pool))]
        parent2 = parents_pool[int(random.random() * len(parents_pool))]
        children.append(breed(parent1,parent2))
    return children

# %%
def mutation(children_set):
    for i in range(len(children_set)):
        if random.random() > 0.3:
            continue
        else:
            mutated_position = int(random.random() * passcode_length)
#             mutation = int(round(random.uniform(passcode_lower_bound,passcode_upper_bound+1),0))
            mutation = str(np.random.choice(passcode_options, 1)[0])
            children_set[i][mutated_position] = mutation
    return children_set

# %%
success = []
generations = 0
t0 = time.time()
while True:

    fitness_scores = fitness(population)
    success.append(max([i[1] for i in fitness_scores]))
    if max([i[1] for i in fitness_scores]) == passcode_length:
        print("Cracked in {} generations, and {} seconds! \nSecret passcode = {} \nDiscovered passcode = {}".format(generations,time.time() - t0,['',''],[i[0] for i in fitness_scores if i[1] == passcode_length][0]))
        break
    parents = select_parents(fitness_scores)
    children = create_children(parents)
    population = mutation(children)
    generations += 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a4f638ba80d8> in <module>
#      11     parents = select_parents(fitness_scores)
#      12     children = create_children(parents)
# ---> 13     population = mutation(children)
#      14     generations += 1
#      15
#
# <ipython-input-10-dd19d4f085da> in mutation(children_set)
#       6             mutated_position = int(random.random() * passcode_length)
#       7 #             mutation = int(round(random.uniform(passcode_lower_bound,passcode_upper_bound+1),0))
# ----> 8             mutation = str(np.random.choice(passcode_options, 1)[0])
#       9             children_set[i][mutated_position] = mutation
#      10     return children_set
#
# mtrand.pyx in mtrand.RandomState.choice()
#
# KeyboardInterrupt:

# %%
fig = plt.figure()
plt.plot(list(range(generations+1)), success)
fig.suptitle('Fitness Score by Generation', fontsize=14, fontweight='bold')
ax = fig.add_subplot(111)
ax.set_xlabel('Generation')
ax.set_ylabel('Fitness Score')
plt.show()
